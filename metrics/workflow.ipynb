# %%
# !pip install requests pandas
# Out:
# Collecting requests
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (2.3.0)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.23.2 in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/adamshafikjovine/Documents/BOScheduling/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp311-cp311-macosx_10_9_universal2.whl (198 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Installing collected packages: urllib3, idna, charset_normalizer, certifi, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [requests]
# Successfully installed certifi-2025.6.15 charset_normalizer-3.4.2 idna-3.10 requests-2.32.4 urllib3-2.5.0

# %%
#!/usr/bin/env python3
"""
G2 Cluster script to upload CSV results to Flask API
Run this after your MIP/Bayesian optimization algorithms complete
"""

import requests
import os
import glob
import logging
from pathlib import Path
import time
from typing import List, Dict
import sys

# Configuration
API_BASE_URL = "http://cornellschedulingteam.orie.cornell.edu:8000"  # Replace with your actual website URL
#API_BASE_URL = "http://localhost:8000"#'http://0.0.0.0:8000'#"http://localhost:8000"
API_KEY = ''#'your-production-secret-key-here-change-this'#os.environ.get("UPLOAD_API_KEY", "your-secret-api-key-here")
RESULTS_DIR = "../results"  # Directory where your CSVs are generated
RETRY_ATTEMPTS = 3
RETRY_DELAY = 5  # seconds

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s: %(message)s",
    handlers=[
        logging.FileHandler("upload_results.log"),
        logging.StreamHandler(sys.stdout),
    ],
)
logger = logging.getLogger(__name__)


def find_csv_files(directory: str) -> List[str]:
    """Find all CSV files in the results directory"""
    csv_pattern = os.path.join(directory, "sp25/metrics/20250614*.csv")
    csv_files = glob.glob(csv_pattern, recursive=True)

    # Filter out any files you don't want to upload
    # Example: exclude temporary or intermediate files
    filtered_files = [f for f in csv_files if not f.endswith("_temp.csv")]

    logger.info(f"Found {len(filtered_files)} CSV files to upload")
    return filtered_files


def upload_files_to_api(csv_files: List[str]) -> Dict:
    """Upload CSV files to the Flask API"""

    # Prepare files for upload
    files = []
    try:
        for csv_file in csv_files:
            files.append(
                (
                    "files",
                    (os.path.basename(csv_file), open(csv_file, "rb"), "text/csv"),
                )
            )

        # Prepare headers
        headers = {"X-API-Key": API_KEY}

        # Make the request
        logger.info(
            f"Uploading {len(csv_files)} files to {API_BASE_URL}/api/upload-metrics"
        )

        response = requests.post(
            f"{API_BASE_URL}/api/upload-metrics",
            files=files,
            headers=headers,
            timeout=300,  # 5 minute timeout for large files
        )

        # Parse response
        if response.status_code in [200, 207]:  # 207 = partial success
            result = response.json()
            logger.info(f"Upload successful: {result}")
            return result
        else:
            logger.error(f"Upload failed: {response.status_code} - {response.text}")
            return {"error": f"HTTP {response.status_code}: {response.text}"}

    except requests.exceptions.RequestException as e:
        logger.error(f"Network error during upload: {e}")
        return {"error": f"Network error: {e}"}

    except Exception as e:
        logger.error(f"Unexpected error during upload: {e}")
        return {"error": f"Unexpected error: {e}"}

    finally:
        # Close all file handles
        for _, file_tuple in files:
            if len(file_tuple) >= 2 and hasattr(file_tuple[1], "close"):
                file_tuple[1].close()


def upload_with_retry(csv_files: List[str]) -> bool:
    """Upload files with retry logic"""

    for attempt in range(1, RETRY_ATTEMPTS + 1):
        logger.info(f"Upload attempt {attempt}/{RETRY_ATTEMPTS}")

        result = upload_files_to_api(csv_files)

        if "error" not in result:
            # Success
            processed_files = result.get("processed_files", [])
            errors = result.get("errors", [])

            logger.info(f"Successfully processed {len(processed_files)} files")

            if errors:
                logger.warning(f"Some files had errors: {errors}")

            return True
        else:
            # Error occurred
            logger.error(f"Attempt {attempt} failed: {result['error']}")

            if attempt < RETRY_ATTEMPTS:
                logger.info(f"Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)

    logger.error(f"All {RETRY_ATTEMPTS} attempts failed")
    return False


def check_api_health() -> bool:
    """Check if the API is accessible"""
    try:
        response = requests.get(f"{API_BASE_URL}/api/upload-status", timeout=10)
        if response.status_code == 200:
            status = response.json()
            logger.info(f"API health check passed: {status}")
            return True
        else:
            logger.error(f"API health check failed: {response.status_code}")
            return False
    except Exception as e:
        logger.error(f"API health check error: {e}")
        return False


def main():
    """Main function to run the upload process"""
    logger.info("Starting CSV upload process")

    # Check if results directory exists
    if not os.path.exists(RESULTS_DIR):
        logger.error(f"Results directory not found: {RESULTS_DIR}")
        sys.exit(1)

    # Check API health
    if not check_api_health():
        logger.error("API health check failed. Aborting upload.")
        sys.exit(1)

    # Find CSV files
    csv_files = find_csv_files(RESULTS_DIR)
    print(csv_files)
    if not csv_files:
        logger.warning("No CSV files found to upload")
        return

    # Upload files
    success = upload_with_retry(csv_files)

    if success:
        logger.info("Upload process completed successfully")

        # Optional: Archive or cleanup uploaded files
        # archive_uploaded_files(csv_files)

    else:
        logger.error("Upload process failed")
        sys.exit(1)


def archive_uploaded_files(csv_files: List[str]):
    """Optional: Move uploaded files to archive directory"""
    archive_dir = os.path.join(RESULTS_DIR, "uploaded")
    os.makedirs(archive_dir, exist_ok=True)

    for csv_file in csv_files:
        archive_path = os.path.join(archive_dir, os.path.basename(csv_file))
        os.rename(csv_file, archive_path)
        logger.info(f"Archived {csv_file} to {archive_path}")


if __name__ == "__main__":
    main()
# Out:
# 2025-07-04 17:37:59,271 INFO: Starting CSV upload process
# 2025-07-04 17:37:59,536 INFO: API health check passed: {'database_connected': True, 'max_file_size_mb': 0, 'metrics_count': 4527, 'status': 'healthy', 'timestamp': '2025-07-04T16:37:59.727753', 'upload_folder': ''}
# 2025-07-04 17:37:59,598 INFO: Found 214 CSV files to upload
# ['../results/sp25/metrics/20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7.csv', '../results/sp25/metrics/20250614_075849i32-53cb986b35a7d9441e28cddd65901951.csv', '../results/sp25/metrics/20250614_192306i183-098df1d9bd308e5472d31178e543d735.csv', '../results/sp25/metrics/20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86.csv', '../results/sp25/metrics/20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a.csv', '../results/sp25/metrics/20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b.csv', '../results/sp25/metrics/20250614_192306i119-a0820601e913ecd013f07d57c77640be.csv', '../results/sp25/metrics/20250614_192306i114-27199c46d176e9419702bb9522f617fa.csv', '../results/sp25/metrics/20250614_192306i140-9013cd903892a340caa5a43c2972fac9.csv', '../results/sp25/metrics/20250614_192306i161-30a1577607ba378054af5a9db9cb07b3.csv', '../results/sp25/metrics/20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d.csv', '../results/sp25/metrics/20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88.csv', '../results/sp25/metrics/20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8.csv', '../results/sp25/metrics/20250614_192306i14-ae3053e740347978092f3dba5b0f2414.csv', '../results/sp25/metrics/20250614_192306i151-145c71226b10591be810bd62f290c9a0.csv', '../results/sp25/metrics/20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2.csv', '../results/sp25/metrics/20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe.csv', '../results/sp25/metrics/20250614_192306i138-111a564af814066182e97cb7b82c1e26.csv', '../results/sp25/metrics/20250614_192306i115-bcfdce8ee96e378c3123451962da98be.csv', '../results/sp25/metrics/20250614_192306i32-699ba935ce96b374aa71f33694d16136.csv', '../results/sp25/metrics/20250614_192306i171-59643d4676349fc7cd3095f69c5664ee.csv', '../results/sp25/metrics/20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de.csv', '../results/sp25/metrics/20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6.csv', '../results/sp25/metrics/20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8.csv', '../results/sp25/metrics/20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69.csv', '../results/sp25/metrics/20250614_192306i30-812b144b141744107638e089258e4d93.csv', '../results/sp25/metrics/20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1.csv', '../results/sp25/metrics/20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6.csv', '../results/sp25/metrics/20250614_192306i105-0af5f99baafa362c37c6604afcf887c1.csv', '../results/sp25/metrics/20250614_192306i21-dc800016dd0a34c5e55feabba7fa9133.csv', '../results/sp25/metrics/20250614_192306i66-2e2d714071a28cc4c6aed197a1e683ad.csv', '../results/sp25/metrics/20250614_192306i64-ac29d2644da4ee812c020dd5713549de.csv', '../results/sp25/metrics/20250614_192306i61-cfc6bb008f4e4db799da498531f2295b.csv', '../results/sp25/metrics/20250614_192306i142-3ca08dc755fe6826e69bfeecba9cfaf6.csv', '../results/sp25/metrics/20250614_192306i158-456324681a0426d819d6f15d5e3bbec2.csv', '../results/sp25/metrics/20250614_192306i11-643dc5082d668033d7c4ebd4af4ba363.csv', '../results/sp25/metrics/20250614_192306i189-da9337b09e662ebfd15a5deb35030e5e.csv', '../results/sp25/metrics/20250614_075849i19-fe52c298959434605e7d02f6ce94ebf0.csv', '../results/sp25/metrics/20250614_192306i107-49b175997bcee4b2332ae4b81e779210.csv', '../results/sp25/metrics/20250614_075849i18-7250af83cc5000f6b43fad4d17b9ec48.csv', '../results/sp25/metrics/20250614_192306i159-0e6b71743e093b2fd2021fb71b5a2755.csv', '../results/sp25/metrics/20250614_192306i141-77ea3ba4eb69aa183a1ad317005d318d.csv', '../results/sp25/metrics/20250614_192306i15-8eb0db5f57decf179479e5c8be013381.csv', '../results/sp25/metrics/20250614_192306i68-e243035c3158a906a77896ba71ce78fc.csv', '../results/sp25/metrics/20250614_192306i113-ca404054c80c4c2bbae96abf718ad802.csv', '../results/sp25/metrics/20250614_192306i88-961be3183a44e926c324162558ff9418.csv', '../results/sp25/metrics/20250614_075849i36-8173c74a9381334bc1acc52a40577c34.csv', '../results/sp25/metrics/20250614_192306i155-90cfe2fed13e5f0a5354f7afbab1f81d.c ...
# 2025-07-04 17:37:59,619 INFO: Upload attempt 1/3
# 2025-07-04 17:37:59,775 INFO: Uploading 214 files to http://cornellschedulingteam.orie.cornell.edu:8000/api/upload-metrics
# 2025-07-04 17:38:01,413 INFO: Upload successful: {'errors': [], 'processed_files': [{'filename': '20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_075849i32-53cb986b35a7d9441e28cddd65901951.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i183-098df1d9bd308e5472d31178e543d735.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i119-a0820601e913ecd013f07d57c77640be.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i114-27199c46d176e9419702bb9522f617fa.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i140-9013cd903892a340caa5a43c2972fac9.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i161-30a1577607ba378054af5a9db9cb07b3.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i14-ae3053e740347978092f3dba5b0f2414.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i151-145c71226b10591be810bd62f290c9a0.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i138-111a564af814066182e97cb7b82c1e26.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i115-bcfdce8ee96e378c3123451962da98be.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i32-699ba935ce96b374aa71f33694d16136.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i171-59643d4676349fc7cd3095f69c5664ee.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i30-812b144b141744107638e089258e4d93.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6.csv', 'metrics_inserted': 1, 'rows_processed': 1, 'status': 'success'}, {'filename': '20250614_192306i105-0af5f99 ...
# 2025-07-04 17:38:01,553 INFO: Successfully processed 214 files
# 2025-07-04 17:38:01,558 INFO: Upload process completed successfully

# %%
#!/usr/bin/env python3
"""
G2 Cluster script to upload schedule CSV results to Flask API
Run this after your scheduling algorithms complete
"""

import requests
import os
import glob
import logging
from pathlib import Path
import time
from typing import List, Dict
import sys

# Configuration
#API_BASE_URL = "http://cornellschedulingteam.orie.cornell.edu:8000"  # Replace with your actual website URL
API_BASE_URL = "http://localhost:8000"  # Uncomment for local testing
API_KEY = ''  # 'your-production-secret-key-here-change-this'
SCHEDULES_DIR = "/Users/adamshafikjovine/Documents/BOScheduling/results/sp25/schedules"  # Directory where your schedule CSVs are generated
SEMESTER = "sp25"  # Current semester
RETRY_ATTEMPTS = 3
RETRY_DELAY = 5  # seconds

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s: %(message)s",
    handlers=[
        logging.FileHandler("upload_schedules.log"),
        logging.StreamHandler(sys.stdout),
    ],
)
logger = logging.getLogger(__name__)


def find_schedule_csv_files(directory: str) -> List[str]:
    """Find all schedule CSV files in the schedules directory"""
    csv_pattern = os.path.join(directory, "20250614*.csv")
    csv_files = glob.glob(csv_pattern, recursive=False)

    # Filter out any files you don't want to upload
    # Example: exclude temporary, backup, or test files
    filtered_files = [
        f for f in csv_files 
        if not any(exclude in os.path.basename(f).lower() 
                  for exclude in ["_temp", "_backup", "_test", "temp_"])
    ]

    logger.info(f"Found {len(filtered_files)} schedule CSV files to upload")
    return filtered_files


def upload_schedules_to_api(csv_files: List[str], semester: str) -> Dict:
    """Upload schedule CSV files to the Flask API"""

    # Prepare files for upload
    files = []
    try:
        for csv_file in csv_files:
            files.append(
                (
                    "files",
                    (os.path.basename(csv_file), open(csv_file, "rb"), "text/csv"),
                )
            )

        # Prepare headers and form data
        headers = {"X-API-Key": API_KEY}
        data = {"semester": semester}

        # Make the request
        logger.info(
            f"Uploading {len(csv_files)} schedule files to {API_BASE_URL}/api/upload-schedules"
        )

        response = requests.post(
            f"{API_BASE_URL}/api/upload-schedules",
            files=files,
            data=data,
            headers=headers,
            timeout=300,  # 5 minute timeout for large files
        )

        # Parse response
        if response.status_code in [200, 207]:  # 207 = partial success
            result = response.json()
            logger.info(f"Schedule upload successful: {result.get('message', 'Success')}")
            
            # Log details about processed files
            for file_result in result.get('processed_files', []):
                filename = file_result.get('filename', 'Unknown')
                if file_result.get('error'):
                    logger.warning(f"  {filename}: ERROR - {file_result['error']}")
                else:
                    records = file_result.get('records_processed', 0)
                    schedule_id = file_result.get('schedule_id', 'Unknown')
                    logger.info(f"  {filename}: SUCCESS - {records} records for schedule {schedule_id}")
            
            return result
        else:
            logger.error(f"Schedule upload failed: {response.status_code} - {response.text}")
            return {"error": f"HTTP {response.status_code}: {response.text}"}

    except requests.exceptions.RequestException as e:
        logger.error(f"Network error during schedule upload: {e}")
        return {"error": f"Network error: {e}"}

    except Exception as e:
        logger.error(f"Unexpected error during schedule upload: {e}")
        return {"error": f"Unexpected error: {e}"}

    finally:
        # Close all file handles
        for _, file_tuple in files:
            if len(file_tuple) >= 2 and hasattr(file_tuple[1], "close"):
                file_tuple[1].close()


def upload_schedules_with_retry(csv_files: List[str], semester: str) -> bool:
    """Upload schedule files with retry logic"""

    for attempt in range(1, RETRY_ATTEMPTS + 1):
        logger.info(f"Schedule upload attempt {attempt}/{RETRY_ATTEMPTS}")

        result = upload_schedules_to_api(csv_files, semester)

        if "error" not in result:
            # Success
            processed_files = result.get("processed_files", [])
            total_records = result.get("total_records", 0)

            logger.info(f"Successfully processed {len(processed_files)} files, {total_records} total records")

            # Check for any file-level errors
            file_errors = [f for f in processed_files if f.get('error')]
            if file_errors:
                logger.warning(f"Some files had errors:")
                for error_file in file_errors:
                    logger.warning(f"  {error_file['filename']}: {error_file['error']}")

            return True
        else:
            # Error occurred
            logger.error(f"Attempt {attempt} failed: {result['error']}")

            if attempt < RETRY_ATTEMPTS:
                logger.info(f"Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)

    logger.error(f"All {RETRY_ATTEMPTS} attempts failed")
    return False


def check_schedule_api_health() -> bool:
    """Check if the schedule API is accessible"""
    try:
        response = requests.get(f"{API_BASE_URL}/api/schedule-upload-status", timeout=10)
        if response.status_code == 200:
            status = response.json()
            logger.info(f"Schedule API health check passed: {status.get('message', 'OK')}")
            total_records = status.get('total_schedule_records', 0)
            logger.info(f"Current database contains {total_records} schedule records")
            return True
        else:
            logger.error(f"Schedule API health check failed: {response.status_code}")
            return False
    except Exception as e:
        logger.error(f"Schedule API health check error: {e}")
        return False


def main():
    """Main function to run the schedule upload process"""
    logger.info(f"Starting schedule CSV upload process for semester: {SEMESTER}")

    # Check if schedules directory exists
    if not os.path.exists(SCHEDULES_DIR):
        logger.error(f"Schedules directory not found: {SCHEDULES_DIR}")
        sys.exit(1)

    # Check API health
    if not check_schedule_api_health():
        logger.error("Schedule API health check failed. Aborting upload.")
        sys.exit(1)

    # Find schedule CSV files
    csv_files = find_schedule_csv_files(SCHEDULES_DIR)
    logger.info(f"Schedule files found: {[os.path.basename(f) for f in csv_files]}")
    
    if not csv_files:
        logger.warning("No schedule CSV files found to upload")
        return

    # Upload files
    success = upload_schedules_with_retry(csv_files, SEMESTER)

    if success:
        logger.info("Schedule upload process completed successfully")

        # Optional: Archive or cleanup uploaded files
        # archive_uploaded_schedule_files(csv_files)

    else:
        logger.error("Schedule upload process failed")
        sys.exit(1)


def archive_uploaded_schedule_files(csv_files: List[str]):
    """Optional: Move uploaded schedule files to archive directory"""
    archive_dir = os.path.join(SCHEDULES_DIR, "uploaded")
    os.makedirs(archive_dir, exist_ok=True)

    for csv_file in csv_files:
        archive_path = os.path.join(archive_dir, os.path.basename(csv_file))
        os.rename(csv_file, archive_path)
        logger.info(f"Archived {csv_file} to {archive_path}")


if __name__ == "__main__":
    main()
# Out:
# 2025-07-04 19:17:58,715 INFO: Starting schedule CSV upload process for semester: sp25
# 2025-07-04 19:18:08,670 INFO: Schedule API health check passed: Schedule upload service is operational
# 2025-07-04 19:18:08,676 INFO: Current database contains 3586742 schedule records
# 2025-07-04 19:18:08,759 INFO: Found 234 schedule CSV files to upload
# 2025-07-04 19:18:08,760 INFO: Schedule files found: ['20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7.csv', '20250614_075849i32-53cb986b35a7d9441e28cddd65901951.csv', '20250614_192306i183-098df1d9bd308e5472d31178e543d735.csv', '20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86.csv', '20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a.csv', '20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b.csv', '20250614_192306i119-a0820601e913ecd013f07d57c77640be.csv', '20250614_192306i114-27199c46d176e9419702bb9522f617fa.csv', '20250614_192306i140-9013cd903892a340caa5a43c2972fac9.csv', '20250614_181924i1-942856b0e73d31921e4355bf54b03c4b.csv', '20250614_192306i161-30a1577607ba378054af5a9db9cb07b3.csv', '20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d.csv', '20250614_191208i5-43ce82620e8d98825f18995c5cbbbfa1.csv', '20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88.csv', '20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8.csv', '20250614_192306i14-ae3053e740347978092f3dba5b0f2414.csv', '20250614_192306i151-145c71226b10591be810bd62f290c9a0.csv', '20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2.csv', '20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe.csv', '20250614_192306i138-111a564af814066182e97cb7b82c1e26.csv', '20250614_190410i2-e3326eb13e1b2912f3ff4581e84cb669.csv', '20250614_192306i115-bcfdce8ee96e378c3123451962da98be.csv', '20250614_192306i32-699ba935ce96b374aa71f33694d16136.csv', '20250614_192306i171-59643d4676349fc7cd3095f69c5664ee.csv', '20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de.csv', '20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6.csv', '20250614_181924i5-81500d4605d7b6bd308980da6922a21a.csv', '20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8.csv', '20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69.csv', '20250614_192306i30-812b144b141744107638e089258e4d93.csv', '20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1.csv', '20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6.csv', '20250614_192306i105-0af5f99baafa362c37c6604afcf887c1.csv', '20250614_192306i21-dc800016dd0a34c5e55feabba7fa9133.csv', '20250614_192306i66-2e2d714071a28cc4c6aed197a1e683ad.csv', '20250614_192306i64-ac29d2644da4ee812c020dd5713549de.csv', '20250614_192306i61-cfc6bb008f4e4db799da498531f2295b.csv', '20250614_192306i142-3ca08dc755fe6826e69bfeecba9cfaf6.csv', '20250614_192306i158-456324681a0426d819d6f15d5e3bbec2.csv', '20250614_192306i11-643dc5082d668033d7c4ebd4af4ba363.csv', '20250614_192306i189-da9337b09e662ebfd15a5deb35030e5e.csv', '20250614_075849i19-fe52c298959434605e7d02f6ce94ebf0.csv', '20250614_192306i107-49b175997bcee4b2332ae4b81e779210.csv', '20250614_075849i18-7250af83cc5000f6b43fad4d17b9ec48.csv', '20250614_192306i159-0e6b71743e093b2fd2021fb71b5a2755.csv', '20250614_192306i141-77ea3ba4eb69aa183a1ad317005d318d.csv', '20250614_192306i15-8eb0db5f57decf179479e5c8be013381.csv', '20250614_192306i68-e243035c3158a906a77896ba71ce78fc.csv', '20250614_192306i113-ca404054c80c4c2bbae96abf718ad802.csv', '20250614_192306i88-961be3183a44e926c324162558ff9418.csv', '20250614_075849i36-8173c74a9381334bc1acc52a40577c34.csv', '20250614_192306i155-90cfe2fed13e5f0a5354f7afbab1f81d.csv', '20250614_075849i39-d08dbb9ebcbdecf83617e81cc86a7fe8.csv', '20250614_192306i70-16f6e9202bd48632144f0e19cb488162.csv', '20250614_192306i122-4e7f9bb88aab2d81a996fa245c22294b.csv', '20250614_181924i3-030ab17aaa57d078fabb7e53d71cd970.csv', '20250614_192306i38-3e84957e52fba0be95c87200f8f590dc.csv', '20250614_192306i136-dc448e95cfab126b9c1355615d4a5863.csv', '20250614_192306i156-67bd7d5ee5d4387f7c968f4dd54f415a.csv', '20250614_192306i150-df6c29c5f62d37ed97aab7ec3bb7333d.csv', '20250614_192306i31-1342ca27cc5159c4ab46907848b60f5f.csv', '20250614_192306i182-f46888bb5ded4e10d4ff1618710f09b4.csv', '20250614_192306i147-f92bbe50c1a7ddc36225973544d24255.csv', '20250614_192306i76-eca4e070785088464361f6f06fe7807e.csv', '20250614_192306i75-1e01350f9105362cdf4eb38cbc3bf2e5.csv', '20250614_190340i4-beb83867db139191ee0c774e5fa1fe64.csv', '20250614_190340i5-ed7e2e794ef6b9 ...
# 2025-07-04 19:18:08,761 INFO: Schedule upload attempt 1/3
# 2025-07-04 19:18:08,784 INFO: Uploading 234 schedule files to http://localhost:8000/api/upload-schedules
# 2025-07-04 19:18:12,286 INFO: Schedule upload successful: Processed 234 files, 120840 total records
# 2025-07-04 19:18:12,290 INFO:   20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7.csv: SUCCESS - 570 records for schedule 20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7
# 2025-07-04 19:18:12,290 INFO:   20250614_075849i32-53cb986b35a7d9441e28cddd65901951.csv: SUCCESS - 570 records for schedule 20250614_075849i32-53cb986b35a7d9441e28cddd65901951
# 2025-07-04 19:18:12,291 INFO:   20250614_192306i183-098df1d9bd308e5472d31178e543d735.csv: SUCCESS - 570 records for schedule 20250614_192306i183-098df1d9bd308e5472d31178e543d735
# 2025-07-04 19:18:12,291 INFO:   20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86.csv: SUCCESS - 570 records for schedule 20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86
# 2025-07-04 19:18:12,292 INFO:   20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a.csv: SUCCESS - 570 records for schedule 20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a
# 2025-07-04 19:18:12,292 INFO:   20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b.csv: SUCCESS - 570 records for schedule 20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b
# 2025-07-04 19:18:12,292 INFO:   20250614_192306i119-a0820601e913ecd013f07d57c77640be.csv: SUCCESS - 570 records for schedule 20250614_192306i119-a0820601e913ecd013f07d57c77640be
# 2025-07-04 19:18:12,292 INFO:   20250614_192306i114-27199c46d176e9419702bb9522f617fa.csv: SUCCESS - 570 records for schedule 20250614_192306i114-27199c46d176e9419702bb9522f617fa
# 2025-07-04 19:18:12,293 INFO:   20250614_192306i140-9013cd903892a340caa5a43c2972fac9.csv: SUCCESS - 570 records for schedule 20250614_192306i140-9013cd903892a340caa5a43c2972fac9
# 2025-07-04 19:18:12,293 WARNING:   20250614_181924i1-942856b0e73d31921e4355bf54b03c4b.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,293 INFO:   20250614_192306i161-30a1577607ba378054af5a9db9cb07b3.csv: SUCCESS - 570 records for schedule 20250614_192306i161-30a1577607ba378054af5a9db9cb07b3
# 2025-07-04 19:18:12,294 INFO:   20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d.csv: SUCCESS - 570 records for schedule 20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d
# 2025-07-04 19:18:12,294 WARNING:   20250614_191208i5-43ce82620e8d98825f18995c5cbbbfa1.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,294 INFO:   20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88.csv: SUCCESS - 570 records for schedule 20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88
# 2025-07-04 19:18:12,295 INFO:   20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8.csv: SUCCESS - 570 records for schedule 20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8
# 2025-07-04 19:18:12,295 INFO:   20250614_192306i14-ae3053e740347978092f3dba5b0f2414.csv: SUCCESS - 570 records for schedule 20250614_192306i14-ae3053e740347978092f3dba5b0f2414
# 2025-07-04 19:18:12,295 INFO:   20250614_192306i151-145c71226b10591be810bd62f290c9a0.csv: SUCCESS - 570 records for schedule 20250614_192306i151-145c71226b10591be810bd62f290c9a0
# 2025-07-04 19:18:12,295 INFO:   20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2.csv: SUCCESS - 570 records for schedule 20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2
# 2025-07-04 19:18:12,296 INFO:   20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe.csv: SUCCESS - 570 records for schedule 20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe
# 2025-07-04 19:18:12,296 INFO:   20250614_192306i138-111a564af814066182e97cb7b82c1e26.csv: SUCCESS - 570 records for schedule 20250614_192306i138-111a564af814066182e97cb7b82c1e26
# 2025-07-04 19:18:12,296 WARNING:   20250614_190410i2-e3326eb13e1b2912f3ff4581e84cb669.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,297 INFO:   20250614_192306i115-bcfdce8ee96e378c3123451962da98be.csv: SUCCESS - 570 records for schedule 20250614_192306i115-bcfdce8ee96e378c3123451962da98be
# 2025-07-04 19:18:12,297 INFO:   20250614_192306i32-699ba935ce96b374aa71f33694d16136.csv: SUCCESS - 570 records for schedule 20250614_192306i32-699ba935ce96b374aa71f33694d16136
# 2025-07-04 19:18:12,297 INFO:   20250614_192306i171-59643d4676349fc7cd3095f69c5664ee.csv: SUCCESS - 570 records for schedule 20250614_192306i171-59643d4676349fc7cd3095f69c5664ee
# 2025-07-04 19:18:12,297 INFO:   20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de.csv: SUCCESS - 570 records for schedule 20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de
# 2025-07-04 19:18:12,298 INFO:   20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6.csv: SUCCESS - 570 records for schedule 20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6
# 2025-07-04 19:18:12,298 WARNING:   20250614_181924i5-81500d4605d7b6bd308980da6922a21a.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,298 INFO:   20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8.csv: SUCCESS - 570 records for schedule 20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8
# 2025-07-04 19:18:12,298 INFO:   20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69.csv: SUCCESS - 570 records for schedule 20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69
# 2025-07-04 19:18:12,298 INFO:   20250614_192306i30-812b144b141744107638e089258e4d93.csv: SUCCESS - 570 records for schedule 20250614_192306i30-812b144b141744107638e089258e4d93
# 2025-07-04 19:18:12,299 INFO:   20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1.csv: SUCCESS - 570 records for schedule 20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1
# 2025-07-04 19:18:12,299 INFO:   20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6.csv: SUCCESS - 570 records for schedule 20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6
# 2025-07-04 19:18:12,299 INFO:   20250614_192306i105-0af5f99baafa362c37c6604afcf887c1.csv: SUCCESS - 570 records for schedule 20250614_192306i105-0af5f99baafa362c37c6604afcf887c1
# 2025-07-04 19:18:12,299 INFO:   20250614_192306i21-dc800016dd0a34c5e55feabba7fa9133.csv: SUCCESS - 570 records for schedule 20250614_192306i21-dc800016dd0a34c5e55feabba7fa9133
# 2025-07-04 19:18:12,299 INFO:   20250614_192306i66-2e2d714071a28cc4c6aed197a1e683ad.csv: SUCCESS - 570 records for schedule 20250614_192306i66-2e2d714071a28cc4c6aed197a1e683ad
# 2025-07-04 19:18:12,300 INFO:   20250614_192306i64-ac29d2644da4ee812c020dd5713549de.csv: SUCCESS - 570 records for schedule 20250614_192306i64-ac29d2644da4ee812c020dd5713549de
# 2025-07-04 19:18:12,300 INFO:   20250614_192306i61-cfc6bb008f4e4db799da498531f2295b.csv: SUCCESS - 570 records for schedule 20250614_192306i61-cfc6bb008f4e4db799da498531f2295b
# 2025-07-04 19:18:12,300 INFO:   20250614_192306i142-3ca08dc755fe6826e69bfeecba9cfaf6.csv: SUCCESS - 570 records for schedule 20250614_192306i142-3ca08dc755fe6826e69bfeecba9cfaf6
# 2025-07-04 19:18:12,300 INFO:   20250614_192306i158-456324681a0426d819d6f15d5e3bbec2.csv: SUCCESS - 570 records for schedule 20250614_192306i158-456324681a0426d819d6f15d5e3bbec2
# 2025-07-04 19:18:12,301 INFO:   20250614_192306i11-643dc5082d668033d7c4ebd4af4ba363.csv: SUCCESS - 570 records for schedule 20250614_192306i11-643dc5082d668033d7c4ebd4af4ba363
# 2025-07-04 19:18:12,301 INFO:   20250614_192306i189-da9337b09e662ebfd15a5deb35030e5e.csv: SUCCESS - 570 records for schedule 20250614_192306i189-da9337b09e662ebfd15a5deb35030e5e
# 2025-07-04 19:18:12,302 INFO:   20250614_075849i19-fe52c298959434605e7d02f6ce94ebf0.csv: SUCCESS - 570 records for schedule 20250614_075849i19-fe52c298959434605e7d02f6ce94ebf0
# 2025-07-04 19:18:12,302 INFO:   20250614_192306i107-49b175997bcee4b2332ae4b81e779210.csv: SUCCESS - 570 records for schedule 20250614_192306i107-49b175997bcee4b2332ae4b81e779210
# 2025-07-04 19:18:12,302 INFO:   20250614_075849i18-7250af83cc5000f6b43fad4d17b9ec48.csv: SUCCESS - 570 records for schedule 20250614_075849i18-7250af83cc5000f6b43fad4d17b9ec48
# 2025-07-04 19:18:12,302 INFO:   20250614_192306i159-0e6b71743e093b2fd2021fb71b5a2755.csv: SUCCESS - 570 records for schedule 20250614_192306i159-0e6b71743e093b2fd2021fb71b5a2755
# 2025-07-04 19:18:12,302 INFO:   20250614_192306i141-77ea3ba4eb69aa183a1ad317005d318d.csv: SUCCESS - 570 records for schedule 20250614_192306i141-77ea3ba4eb69aa183a1ad317005d318d
# 2025-07-04 19:18:12,302 INFO:   20250614_192306i15-8eb0db5f57decf179479e5c8be013381.csv: SUCCESS - 570 records for schedule 20250614_192306i15-8eb0db5f57decf179479e5c8be013381
# 2025-07-04 19:18:12,303 INFO:   20250614_192306i68-e243035c3158a906a77896ba71ce78fc.csv: SUCCESS - 570 records for schedule 20250614_192306i68-e243035c3158a906a77896ba71ce78fc
# 2025-07-04 19:18:12,303 INFO:   20250614_192306i113-ca404054c80c4c2bbae96abf718ad802.csv: SUCCESS - 570 records for schedule 20250614_192306i113-ca404054c80c4c2bbae96abf718ad802
# 2025-07-04 19:18:12,303 INFO:   20250614_192306i88-961be3183a44e926c324162558ff9418.csv: SUCCESS - 570 records for schedule 20250614_192306i88-961be3183a44e926c324162558ff9418
# 2025-07-04 19:18:12,304 INFO:   20250614_075849i36-8173c74a9381334bc1acc52a40577c34.csv: SUCCESS - 570 records for schedule 20250614_075849i36-8173c74a9381334bc1acc52a40577c34
# 2025-07-04 19:18:12,304 INFO:   20250614_192306i155-90cfe2fed13e5f0a5354f7afbab1f81d.csv: SUCCESS - 570 records for schedule 20250614_192306i155-90cfe2fed13e5f0a5354f7afbab1f81d
# 2025-07-04 19:18:12,304 INFO:   20250614_075849i39-d08dbb9ebcbdecf83617e81cc86a7fe8.csv: SUCCESS - 570 records for schedule 20250614_075849i39-d08dbb9ebcbdecf83617e81cc86a7fe8
# 2025-07-04 19:18:12,304 INFO:   20250614_192306i70-16f6e9202bd48632144f0e19cb488162.csv: SUCCESS - 570 records for schedule 20250614_192306i70-16f6e9202bd48632144f0e19cb488162
# 2025-07-04 19:18:12,304 INFO:   20250614_192306i122-4e7f9bb88aab2d81a996fa245c22294b.csv: SUCCESS - 570 records for schedule 20250614_192306i122-4e7f9bb88aab2d81a996fa245c22294b
# 2025-07-04 19:18:12,305 WARNING:   20250614_181924i3-030ab17aaa57d078fabb7e53d71cd970.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,305 INFO:   20250614_192306i38-3e84957e52fba0be95c87200f8f590dc.csv: SUCCESS - 570 records for schedule 20250614_192306i38-3e84957e52fba0be95c87200f8f590dc
# 2025-07-04 19:18:12,306 INFO:   20250614_192306i136-dc448e95cfab126b9c1355615d4a5863.csv: SUCCESS - 570 records for schedule 20250614_192306i136-dc448e95cfab126b9c1355615d4a5863
# 2025-07-04 19:18:12,306 INFO:   20250614_192306i156-67bd7d5ee5d4387f7c968f4dd54f415a.csv: SUCCESS - 570 records for schedule 20250614_192306i156-67bd7d5ee5d4387f7c968f4dd54f415a
# 2025-07-04 19:18:12,306 INFO:   20250614_192306i150-df6c29c5f62d37ed97aab7ec3bb7333d.csv: SUCCESS - 570 records for schedule 20250614_192306i150-df6c29c5f62d37ed97aab7ec3bb7333d
# 2025-07-04 19:18:12,306 INFO:   20250614_192306i31-1342ca27cc5159c4ab46907848b60f5f.csv: SUCCESS - 570 records for schedule 20250614_192306i31-1342ca27cc5159c4ab46907848b60f5f
# 2025-07-04 19:18:12,307 INFO:   20250614_192306i182-f46888bb5ded4e10d4ff1618710f09b4.csv: SUCCESS - 570 records for schedule 20250614_192306i182-f46888bb5ded4e10d4ff1618710f09b4
# 2025-07-04 19:18:12,307 INFO:   20250614_192306i147-f92bbe50c1a7ddc36225973544d24255.csv: SUCCESS - 570 records for schedule 20250614_192306i147-f92bbe50c1a7ddc36225973544d24255
# 2025-07-04 19:18:12,308 INFO:   20250614_192306i76-eca4e070785088464361f6f06fe7807e.csv: SUCCESS - 570 records for schedule 20250614_192306i76-eca4e070785088464361f6f06fe7807e
# 2025-07-04 19:18:12,308 INFO:   20250614_192306i75-1e01350f9105362cdf4eb38cbc3bf2e5.csv: SUCCESS - 570 records for schedule 20250614_192306i75-1e01350f9105362cdf4eb38cbc3bf2e5
# 2025-07-04 19:18:12,308 WARNING:   20250614_190340i4-beb83867db139191ee0c774e5fa1fe64.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,309 WARNING:   20250614_190340i5-ed7e2e794ef6b9ceddd074734d559edf.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,309 INFO:   20250614_075849i38-1c46b69b23456c06e3c3e52e71a816f6.csv: SUCCESS - 570 records for schedule 20250614_075849i38-1c46b69b23456c06e3c3e52e71a816f6
# 2025-07-04 19:18:12,310 INFO:   20250614_192306i93-e03b880e5a9410ed6da6eab9d45bd732.csv: SUCCESS - 570 records for schedule 20250614_192306i93-e03b880e5a9410ed6da6eab9d45bd732
# 2025-07-04 19:18:12,310 INFO:   20250614_192306i100-e86418b6bbbfeef352d8c18a586ed911.csv: SUCCESS - 570 records for schedule 20250614_192306i100-e86418b6bbbfeef352d8c18a586ed911
# 2025-07-04 19:18:12,310 INFO:   20250614_192306i18-749aa50d0e3fb840113d3bdae7165a47.csv: SUCCESS - 570 records for schedule 20250614_192306i18-749aa50d0e3fb840113d3bdae7165a47
# 2025-07-04 19:18:12,310 INFO:   20250614_192306i47-75387112fef49795e951c4202979052b.csv: SUCCESS - 570 records for schedule 20250614_192306i47-75387112fef49795e951c4202979052b
# 2025-07-04 19:18:12,311 INFO:   20250614_192306i50-01510e3817398aef28a46fa260b0696a.csv: SUCCESS - 570 records for schedule 20250614_192306i50-01510e3817398aef28a46fa260b0696a
# 2025-07-04 19:18:12,311 INFO:   20250614_192306i96-f06ad7fa3d0e7398bbd896649ecb6738.csv: SUCCESS - 570 records for schedule 20250614_192306i96-f06ad7fa3d0e7398bbd896649ecb6738
# 2025-07-04 19:18:12,311 INFO:   20250614_192306i109-b0afa3913077b42ea731b8bb2a0832b0.csv: SUCCESS - 570 records for schedule 20250614_192306i109-b0afa3913077b42ea731b8bb2a0832b0
# 2025-07-04 19:18:12,312 INFO:   20250614_075849i30-1cf8b57cb495ea11f1e221404fa9410e.csv: SUCCESS - 570 records for schedule 20250614_075849i30-1cf8b57cb495ea11f1e221404fa9410e
# 2025-07-04 19:18:12,312 INFO:   20250614_192306i86-9d6405573bd06ca54b1449ec26fd9bae.csv: SUCCESS - 570 records for schedule 20250614_192306i86-9d6405573bd06ca54b1449ec26fd9bae
# 2025-07-04 19:18:12,312 INFO:   20250614_192306i25-70789b1153229aea0b165361fe105e77.csv: SUCCESS - 570 records for schedule 20250614_192306i25-70789b1153229aea0b165361fe105e77
# 2025-07-04 19:18:12,312 INFO:   20250614_192306i60-c086bde7c5b4e6a74b0b312e80affd41.csv: SUCCESS - 570 records for schedule 20250614_192306i60-c086bde7c5b4e6a74b0b312e80affd41
# 2025-07-04 19:18:12,312 WARNING:   20250614_190340i3-d5597ce8e03a770be9a16426b577787a.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,313 INFO:   20250614_192306i102-0f783b7886060f3822c0cdad0854616d.csv: SUCCESS - 570 records for schedule 20250614_192306i102-0f783b7886060f3822c0cdad0854616d
# 2025-07-04 19:18:12,313 INFO:   20250614_192306i169-5b06fb3a57180d7c783d79d52a86500f.csv: SUCCESS - 570 records for schedule 20250614_192306i169-5b06fb3a57180d7c783d79d52a86500f
# 2025-07-04 19:18:12,313 INFO:   20250614_192306i7-7bfc522e853539eb4cbe7696ab10be51.csv: SUCCESS - 570 records for schedule 20250614_192306i7-7bfc522e853539eb4cbe7696ab10be51
# 2025-07-04 19:18:12,314 INFO:   20250614_192306i85-ae7bd6aa6cdcf62488bd4a04cd18bcef.csv: SUCCESS - 570 records for schedule 20250614_192306i85-ae7bd6aa6cdcf62488bd4a04cd18bcef
# 2025-07-04 19:18:12,314 INFO:   20250614_075849i23-d6b347f98b27b330e4b6976e790998ba.csv: SUCCESS - 570 records for schedule 20250614_075849i23-d6b347f98b27b330e4b6976e790998ba
# 2025-07-04 19:18:12,314 INFO:   20250614_192306i104-22819fea22eb362c232709b5c7187e4a.csv: SUCCESS - 570 records for schedule 20250614_192306i104-22819fea22eb362c232709b5c7187e4a
# 2025-07-04 19:18:12,314 INFO:   20250614_192306i17-110edb7cdcedd48f5bf023f031f02708.csv: SUCCESS - 570 records for schedule 20250614_192306i17-110edb7cdcedd48f5bf023f031f02708
# 2025-07-04 19:18:12,315 INFO:   20250614_192306i127-9644d2e2e75af6ec8194f772b2d45083.csv: SUCCESS - 570 records for schedule 20250614_192306i127-9644d2e2e75af6ec8194f772b2d45083
# 2025-07-04 19:18:12,315 INFO:   20250614_192306i40-849f406a55945ca366ccf7a19af7f301.csv: SUCCESS - 570 records for schedule 20250614_192306i40-849f406a55945ca366ccf7a19af7f301
# 2025-07-04 19:18:12,316 INFO:   20250614_192306i12-8cfcc46f3e97dd5ee14ea433701f75fd.csv: SUCCESS - 570 records for schedule 20250614_192306i12-8cfcc46f3e97dd5ee14ea433701f75fd
# 2025-07-04 19:18:12,316 INFO:   20250614_192306i124-f4a145a8d89166236243089de5ebc9dc.csv: SUCCESS - 570 records for schedule 20250614_192306i124-f4a145a8d89166236243089de5ebc9dc
# 2025-07-04 19:18:12,317 INFO:   20250614_075849i40-753c89e22723bc11a626cf6d10f7ad92.csv: SUCCESS - 570 records for schedule 20250614_075849i40-753c89e22723bc11a626cf6d10f7ad92
# 2025-07-04 19:18:12,317 INFO:   20250614_192306i51-455ccca9505a20cf8044204b7a169f96.csv: SUCCESS - 570 records for schedule 20250614_192306i51-455ccca9505a20cf8044204b7a169f96
# 2025-07-04 19:18:12,317 INFO:   20250614_192306i167-b04cea0748b055a2ff3f3303b6c579a6.csv: SUCCESS - 570 records for schedule 20250614_192306i167-b04cea0748b055a2ff3f3303b6c579a6
# 2025-07-04 19:18:12,318 WARNING:   20250614_190340i1-7a8baa681c486f27730787b45eeabbad.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,318 INFO:   20250614_192306i82-006d6106a164801d6c072e9f458a6028.csv: SUCCESS - 570 records for schedule 20250614_192306i82-006d6106a164801d6c072e9f458a6028
# 2025-07-04 19:18:12,319 INFO:   20250614_192306i134-7626e0f73d8379638c29ef2c7e0aea2b.csv: SUCCESS - 570 records for schedule 20250614_192306i134-7626e0f73d8379638c29ef2c7e0aea2b
# 2025-07-04 19:18:12,319 INFO:   20250614_192306i39-c4c98088c07559e10f1331da0c229079.csv: SUCCESS - 570 records for schedule 20250614_192306i39-c4c98088c07559e10f1331da0c229079
# 2025-07-04 19:18:12,320 INFO:   20250614_192306i84-d6eaa0d726406daece035ba3ddded8a1.csv: SUCCESS - 570 records for schedule 20250614_192306i84-d6eaa0d726406daece035ba3ddded8a1
# 2025-07-04 19:18:12,320 INFO:   20250614_075849i26-878b4c69f6a55d1d46b3d04f67110e57.csv: SUCCESS - 570 records for schedule 20250614_075849i26-878b4c69f6a55d1d46b3d04f67110e57
# 2025-07-04 19:18:12,320 INFO:   20250614_192306i54-b960cfdf9a4c00c231be66609de6545b.csv: SUCCESS - 570 records for schedule 20250614_192306i54-b960cfdf9a4c00c231be66609de6545b
# 2025-07-04 19:18:12,320 INFO:   20250614_192306i55-64eefbb279df0577700cbfa3a7a2fb89.csv: SUCCESS - 570 records for schedule 20250614_192306i55-64eefbb279df0577700cbfa3a7a2fb89
# 2025-07-04 19:18:12,321 INFO:   20250614_192306i4-d8725c9c5482fccf1e186c93284d17b6.csv: SUCCESS - 570 records for schedule 20250614_192306i4-d8725c9c5482fccf1e186c93284d17b6
# 2025-07-04 19:18:12,321 INFO:   20250614_192306i56-1d19b3762902f9cc3730a2d1eabffe3b.csv: SUCCESS - 570 records for schedule 20250614_192306i56-1d19b3762902f9cc3730a2d1eabffe3b
# 2025-07-04 19:18:12,321 INFO:   20250614_192306i143-8a4d218375e2e787fdd2c94f816edb40.csv: SUCCESS - 570 records for schedule 20250614_192306i143-8a4d218375e2e787fdd2c94f816edb40
# 2025-07-04 19:18:12,322 INFO:   20250614_192306i2-a97419ede372d644c04aefa813a71c74.csv: SUCCESS - 570 records for schedule 20250614_192306i2-a97419ede372d644c04aefa813a71c74
# 2025-07-04 19:18:12,322 WARNING:   20250614_190340i2-9411e19df08fe87fd0e06d2c4e0f2519.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,323 INFO:   20250614_192306i175-a604daff68cefb9873ce6c30e87cc480.csv: SUCCESS - 570 records for schedule 20250614_192306i175-a604daff68cefb9873ce6c30e87cc480
# 2025-07-04 19:18:12,325 INFO:   20250614_192306i90-d6897b399519944ed8ee4a724ff536ad.csv: SUCCESS - 570 records for schedule 20250614_192306i90-d6897b399519944ed8ee4a724ff536ad
# 2025-07-04 19:18:12,326 INFO:   20250614_192306i168-c5df3863f00ebed21232485cc6e7b9f1.csv: SUCCESS - 570 records for schedule 20250614_192306i168-c5df3863f00ebed21232485cc6e7b9f1
# 2025-07-04 19:18:12,328 INFO:   20250614_192306i178-71045229ed8769f036b9c7554e3eb28b.csv: SUCCESS - 570 records for schedule 20250614_192306i178-71045229ed8769f036b9c7554e3eb28b
# 2025-07-04 19:18:12,329 INFO:   20250614_192306i83-97f2593c409dd0f8dc20b8d4ddecf378.csv: SUCCESS - 570 records for schedule 20250614_192306i83-97f2593c409dd0f8dc20b8d4ddecf378
# 2025-07-04 19:18:12,331 INFO:   20250614_192306i6-543aa96d2801f8bad578af1a592d1e52.csv: SUCCESS - 570 records for schedule 20250614_192306i6-543aa96d2801f8bad578af1a592d1e52
# 2025-07-04 19:18:12,333 INFO:   20250614_192306i58-6989a8de2bb881b17fbc4ec3d14a61a4.csv: SUCCESS - 570 records for schedule 20250614_192306i58-6989a8de2bb881b17fbc4ec3d14a61a4
# 2025-07-04 19:18:12,335 INFO:   20250614_192306i152-23a1a38f170f5c1763f90367abfc5767.csv: SUCCESS - 570 records for schedule 20250614_192306i152-23a1a38f170f5c1763f90367abfc5767
# 2025-07-04 19:18:12,336 INFO:   20250614_192306i170-19108ac3facb08bac8366e746178a0e6.csv: SUCCESS - 570 records for schedule 20250614_192306i170-19108ac3facb08bac8366e746178a0e6
# 2025-07-04 19:18:12,337 INFO:   20250614_192306i73-2e24d719152fb232781e6600cf7894fb.csv: SUCCESS - 570 records for schedule 20250614_192306i73-2e24d719152fb232781e6600cf7894fb
# 2025-07-04 19:18:12,338 INFO:   20250614_192306i95-f87a6aa5781164ae48ea621dcfa2205a.csv: SUCCESS - 570 records for schedule 20250614_192306i95-f87a6aa5781164ae48ea621dcfa2205a
# 2025-07-04 19:18:12,338 INFO:   20250614_075849i33-f11a906957dd565d45188aaca066c45c.csv: SUCCESS - 570 records for schedule 20250614_075849i33-f11a906957dd565d45188aaca066c45c
# 2025-07-04 19:18:12,339 INFO:   20250614_192306i121-9b5199edbce0d236f0ca012c033888b9.csv: SUCCESS - 570 records for schedule 20250614_192306i121-9b5199edbce0d236f0ca012c033888b9
# 2025-07-04 19:18:12,339 INFO:   20250614_192306i179-4e4997b086a8f5a7abac0d8b9e159ce8.csv: SUCCESS - 570 records for schedule 20250614_192306i179-4e4997b086a8f5a7abac0d8b9e159ce8
# 2025-07-04 19:18:12,340 INFO:   20250614_075849i25-78321219bd0279c1312ab6ed29bca4db.csv: SUCCESS - 570 records for schedule 20250614_075849i25-78321219bd0279c1312ab6ed29bca4db
# 2025-07-04 19:18:12,341 WARNING:   20250614_190410i5-8cdfd70678853f257c9985097b5b677e.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,342 INFO:   20250614_075849i35-bb9ca99e65f20d23e7242bd9ff5ca218.csv: SUCCESS - 570 records for schedule 20250614_075849i35-bb9ca99e65f20d23e7242bd9ff5ca218
# 2025-07-04 19:18:12,342 INFO:   20250614_075849i29-aad821a31c678b3ab8284e63c8145f73.csv: SUCCESS - 570 records for schedule 20250614_075849i29-aad821a31c678b3ab8284e63c8145f73
# 2025-07-04 19:18:12,343 INFO:   20250614_192306i120-223100d0736a22819c2b817b815d5845.csv: SUCCESS - 570 records for schedule 20250614_192306i120-223100d0736a22819c2b817b815d5845
# 2025-07-04 19:18:12,343 WARNING:   20250614_191208i2-ad7a48a504419455eeb5e262cfea1ff8.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,343 INFO:   20250614_192306i131-749b10bf696b2f821c0091bc1e68e1fa.csv: SUCCESS - 570 records for schedule 20250614_192306i131-749b10bf696b2f821c0091bc1e68e1fa
# 2025-07-04 19:18:12,344 INFO:   20250614_192306i125-00327be486b458c6e6512b12e4897e7b.csv: SUCCESS - 570 records for schedule 20250614_192306i125-00327be486b458c6e6512b12e4897e7b
# 2025-07-04 19:18:12,344 WARNING:   20250614_191208i3-b8ebea855401b919cca763bbfa3e049b.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,345 INFO:   20250614_192306i36-e7dee4b0cc8e8afefe0e4ed4a6313ca0.csv: SUCCESS - 570 records for schedule 20250614_192306i36-e7dee4b0cc8e8afefe0e4ed4a6313ca0
# 2025-07-04 19:18:12,345 INFO:   20250614_192306i148-a2d4275bf4d00323740c4381ddf5f890.csv: SUCCESS - 570 records for schedule 20250614_192306i148-a2d4275bf4d00323740c4381ddf5f890
# 2025-07-04 19:18:12,346 INFO:   20250614_075849i28-4ebd99276c7d36e3a666eb087e541fa7.csv: SUCCESS - 570 records for schedule 20250614_075849i28-4ebd99276c7d36e3a666eb087e541fa7
# 2025-07-04 19:18:12,347 WARNING:   20250614_190410i4-91baa9b3e5235f094d54f9a674abf525.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,348 INFO:   20250614_192306i79-d4170d24c1ea4cf6b4d7aa75d7bde4f8.csv: SUCCESS - 570 records for schedule 20250614_192306i79-d4170d24c1ea4cf6b4d7aa75d7bde4f8
# 2025-07-04 19:18:12,348 INFO:   20250614_192306i166-7089a0c1ab69d0adfd64285cc95bd48a.csv: SUCCESS - 570 records for schedule 20250614_192306i166-7089a0c1ab69d0adfd64285cc95bd48a
# 2025-07-04 19:18:12,350 INFO:   20250614_192306i1-88c271c6ac8f16680c7760ce37737662.csv: SUCCESS - 570 records for schedule 20250614_192306i1-88c271c6ac8f16680c7760ce37737662
# 2025-07-04 19:18:12,352 INFO:   20250614_192306i154-e4e06274bc27307167dd782810e2011a.csv: SUCCESS - 570 records for schedule 20250614_192306i154-e4e06274bc27307167dd782810e2011a
# 2025-07-04 19:18:12,354 WARNING:   20250614_181924i2-24f65e9dc3eeeaa86989220b5d34ac1f.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,355 INFO:   20250614_192306i81-d70ae3a0c95f83b7889fc75d2e316577.csv: SUCCESS - 570 records for schedule 20250614_192306i81-d70ae3a0c95f83b7889fc75d2e316577
# 2025-07-04 19:18:12,359 INFO:   20250614_192306i97-d060a30596adf990e7d62d7a79ed0766.csv: SUCCESS - 570 records for schedule 20250614_192306i97-d060a30596adf990e7d62d7a79ed0766
# 2025-07-04 19:18:12,363 INFO:   20250614_192306i112-7d3bcd9c847bb4ea4d1144e5db8adf7b.csv: SUCCESS - 570 records for schedule 20250614_192306i112-7d3bcd9c847bb4ea4d1144e5db8adf7b
# 2025-07-04 19:18:12,366 INFO:   20250614_192306i188-41782849568a18c8c6a4b65e72ea095f.csv: SUCCESS - 570 records for schedule 20250614_192306i188-41782849568a18c8c6a4b65e72ea095f
# 2025-07-04 19:18:12,367 INFO:   20250614_192306i22-b7d3e8aaaed636ffb5ec59c34c98ac7b.csv: SUCCESS - 570 records for schedule 20250614_192306i22-b7d3e8aaaed636ffb5ec59c34c98ac7b
# 2025-07-04 19:18:12,367 INFO:   20250614_192306i71-36413d79ba463bd85a0f50bb90023654.csv: SUCCESS - 570 records for schedule 20250614_192306i71-36413d79ba463bd85a0f50bb90023654
# 2025-07-04 19:18:12,368 INFO:   20250614_192306i10-efc12cc4e9eee4924080103ffb8cb3ff.csv: SUCCESS - 570 records for schedule 20250614_192306i10-efc12cc4e9eee4924080103ffb8cb3ff
# 2025-07-04 19:18:12,368 INFO:   20250614_192306i176-6c189e25bacce3d60d040b2ff38cb8bc.csv: SUCCESS - 570 records for schedule 20250614_192306i176-6c189e25bacce3d60d040b2ff38cb8bc
# 2025-07-04 19:18:12,369 INFO:   20250614_192306i116-6f275568900b37713152bc105f37c5af.csv: SUCCESS - 570 records for schedule 20250614_192306i116-6f275568900b37713152bc105f37c5af
# 2025-07-04 19:18:12,369 WARNING:   20250614_191208i4-5713d82185c46333a71011fd97b31163.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,369 INFO:   20250614_192306i172-7335a8275a3498e03ee9929864de0d62.csv: SUCCESS - 570 records for schedule 20250614_192306i172-7335a8275a3498e03ee9929864de0d62
# 2025-07-04 19:18:12,370 INFO:   20250614_192306i23-dadb513c68410627968d932edeecb95a.csv: SUCCESS - 570 records for schedule 20250614_192306i23-dadb513c68410627968d932edeecb95a
# 2025-07-04 19:18:12,370 INFO:   20250614_192306i8-303945b9229833556b70a881055cdea7.csv: SUCCESS - 570 records for schedule 20250614_192306i8-303945b9229833556b70a881055cdea7
# 2025-07-04 19:18:12,371 INFO:   20250614_192306i49-4a7a3bf549c0dda5da161e14ee1b33fa.csv: SUCCESS - 570 records for schedule 20250614_192306i49-4a7a3bf549c0dda5da161e14ee1b33fa
# 2025-07-04 19:18:12,371 INFO:   20250614_192306i27-ccedb2aea227ee7c839d429ffb307090.csv: SUCCESS - 570 records for schedule 20250614_192306i27-ccedb2aea227ee7c839d429ffb307090
# 2025-07-04 19:18:12,372 INFO:   20250614_192306i80-ef673b4d340cabbb753ce67c25c24905.csv: SUCCESS - 570 records for schedule 20250614_192306i80-ef673b4d340cabbb753ce67c25c24905
# 2025-07-04 19:18:12,373 INFO:   20250614_192306i181-ed67f247e2034a2abd5face20deff289.csv: SUCCESS - 570 records for schedule 20250614_192306i181-ed67f247e2034a2abd5face20deff289
# 2025-07-04 19:18:12,374 INFO:   20250614_192306i78-2daada8cf9f92d5dd5b8b5c427a51a53.csv: SUCCESS - 570 records for schedule 20250614_192306i78-2daada8cf9f92d5dd5b8b5c427a51a53
# 2025-07-04 19:18:12,374 INFO:   20250614_192306i186-a8305d458c1f483fd70f8ae8d12d7108.csv: SUCCESS - 570 records for schedule 20250614_192306i186-a8305d458c1f483fd70f8ae8d12d7108
# 2025-07-04 19:18:12,375 INFO:   20250614_192306i149-17548a40f9b10699f124814d5a482e1c.csv: SUCCESS - 570 records for schedule 20250614_192306i149-17548a40f9b10699f124814d5a482e1c
# 2025-07-04 19:18:12,375 INFO:   20250614_192306i92-e4b7683bdca8a06bf190e52e879dc05a.csv: SUCCESS - 570 records for schedule 20250614_192306i92-e4b7683bdca8a06bf190e52e879dc05a
# 2025-07-04 19:18:12,375 INFO:   20250614_192306i174-2a535729146411992975153baaa54d46.csv: SUCCESS - 570 records for schedule 20250614_192306i174-2a535729146411992975153baaa54d46
# 2025-07-04 19:18:12,376 INFO:   20250614_192306i72-b7e246e8befc47a481b1ad5059c30836.csv: SUCCESS - 570 records for schedule 20250614_192306i72-b7e246e8befc47a481b1ad5059c30836
# 2025-07-04 19:18:12,376 INFO:   20250614_192306i190-2b62f0c27278d38b0155846365c8a0a9.csv: SUCCESS - 570 records for schedule 20250614_192306i190-2b62f0c27278d38b0155846365c8a0a9
# 2025-07-04 19:18:12,377 INFO:   20250614_192306i111-e32a202837daeb512019da8f3d267f0f.csv: SUCCESS - 570 records for schedule 20250614_192306i111-e32a202837daeb512019da8f3d267f0f
# 2025-07-04 19:18:12,377 INFO:   20250614_075849i22-38575f29a261b426b9a9524c8c2ae2b3.csv: SUCCESS - 570 records for schedule 20250614_075849i22-38575f29a261b426b9a9524c8c2ae2b3
# 2025-07-04 19:18:12,377 INFO:   20250614_192306i126-b7aeadbbdfffc3823ce568289f230c60.csv: SUCCESS - 570 records for schedule 20250614_192306i126-b7aeadbbdfffc3823ce568289f230c60
# 2025-07-04 19:18:12,378 INFO:   20250614_192306i89-938ec509c131b1acc8cf709266e3d523.csv: SUCCESS - 570 records for schedule 20250614_192306i89-938ec509c131b1acc8cf709266e3d523
# 2025-07-04 19:18:12,378 WARNING:   20250614_190410i1-f53c66fa53b8ff8b2912535bc1f5c965.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,378 INFO:   20250614_192306i160-fab900bedfa78e978dae14bb34ffcc53.csv: SUCCESS - 570 records for schedule 20250614_192306i160-fab900bedfa78e978dae14bb34ffcc53
# 2025-07-04 19:18:12,378 INFO:   20250614_192306i13-229d84294299373563cfad5582e6573c.csv: SUCCESS - 570 records for schedule 20250614_192306i13-229d84294299373563cfad5582e6573c
# 2025-07-04 19:18:12,378 INFO:   20250614_192306i33-179366c32a03c5e0be748b969662a899.csv: SUCCESS - 570 records for schedule 20250614_192306i33-179366c32a03c5e0be748b969662a899
# 2025-07-04 19:18:12,379 INFO:   20250614_192306i59-5d5cda608f3c7d976b26d60df42b4989.csv: SUCCESS - 570 records for schedule 20250614_192306i59-5d5cda608f3c7d976b26d60df42b4989
# 2025-07-04 19:18:12,379 WARNING:   20250614_190343i1-deaf561e13e5576a366dfced9666dc37.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,380 INFO:   20250614_192306i63-dd50bc491cdb93c600279d4540a95410.csv: SUCCESS - 570 records for schedule 20250614_192306i63-dd50bc491cdb93c600279d4540a95410
# 2025-07-04 19:18:12,381 INFO:   20250614_192306i106-bc0133bcd255bdbb9b0f4327c8b503fd.csv: SUCCESS - 570 records for schedule 20250614_192306i106-bc0133bcd255bdbb9b0f4327c8b503fd
# 2025-07-04 19:18:12,382 INFO:   20250614_192306i5-9738bd25fa2cedc980a512f9f36ee27b.csv: SUCCESS - 570 records for schedule 20250614_192306i5-9738bd25fa2cedc980a512f9f36ee27b
# 2025-07-04 19:18:12,382 INFO:   20250614_192306i162-a7485925069e27cbfea9fd6ef185961c.csv: SUCCESS - 570 records for schedule 20250614_192306i162-a7485925069e27cbfea9fd6ef185961c
# 2025-07-04 19:18:12,383 INFO:   20250614_192306i52-1530dc9668e003b01f70b946fdf041fe.csv: SUCCESS - 570 records for schedule 20250614_192306i52-1530dc9668e003b01f70b946fdf041fe
# 2025-07-04 19:18:12,383 INFO:   20250614_192306i130-817006358a73a1a35d995fd509919a31.csv: SUCCESS - 570 records for schedule 20250614_192306i130-817006358a73a1a35d995fd509919a31
# 2025-07-04 19:18:12,383 INFO:   20250614_075849i27-96095a9951ca69608779c1237024d392.csv: SUCCESS - 570 records for schedule 20250614_075849i27-96095a9951ca69608779c1237024d392
# 2025-07-04 19:18:12,384 INFO:   20250614_192306i42-f6564b471241b94acb3d4a2aad77eb43.csv: SUCCESS - 570 records for schedule 20250614_192306i42-f6564b471241b94acb3d4a2aad77eb43
# 2025-07-04 19:18:12,385 INFO:   20250614_192306i19-14d2e5cb0c12447989f58819cc3fd3d3.csv: SUCCESS - 570 records for schedule 20250614_192306i19-14d2e5cb0c12447989f58819cc3fd3d3
# 2025-07-04 19:18:12,385 INFO:   20250614_192306i129-94835b0c77ca746b11accf533359fa47.csv: SUCCESS - 570 records for schedule 20250614_192306i129-94835b0c77ca746b11accf533359fa47
# 2025-07-04 19:18:12,386 INFO:   20250614_192306i118-1f720e92fda517c64d9fa27f446ab6c0.csv: SUCCESS - 570 records for schedule 20250614_192306i118-1f720e92fda517c64d9fa27f446ab6c0
# 2025-07-04 19:18:12,386 WARNING:   20250614_181924i4-d97eb563a84b570bd9b5a3fd062a3903.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,386 INFO:   20250614_192306i165-60ef9d6996ad6eab0689d3f6a6634924.csv: SUCCESS - 570 records for schedule 20250614_192306i165-60ef9d6996ad6eab0689d3f6a6634924
# 2025-07-04 19:18:12,386 INFO:   20250614_192306i16-b414852a375a9d723e56d968b43c7da8.csv: SUCCESS - 570 records for schedule 20250614_192306i16-b414852a375a9d723e56d968b43c7da8
# 2025-07-04 19:18:12,387 INFO:   20250614_192306i164-5bf1347002c8e7ac577afdce6b64fac0.csv: SUCCESS - 570 records for schedule 20250614_192306i164-5bf1347002c8e7ac577afdce6b64fac0
# 2025-07-04 19:18:12,387 INFO:   20250614_192306i87-898f94291d22c10ee1b763b5404085b2.csv: SUCCESS - 570 records for schedule 20250614_192306i87-898f94291d22c10ee1b763b5404085b2
# 2025-07-04 19:18:12,387 INFO:   20250614_192306i180-a2d72619e029186d246494e21c9348de.csv: SUCCESS - 570 records for schedule 20250614_192306i180-a2d72619e029186d246494e21c9348de
# 2025-07-04 19:18:12,387 INFO:   20250614_192306i35-8ae1f1c2b8dcc1b86846d1d1a5c21371.csv: SUCCESS - 570 records for schedule 20250614_192306i35-8ae1f1c2b8dcc1b86846d1d1a5c21371
# 2025-07-04 19:18:12,388 INFO:   20250614_192306i48-866539488a7983338aa44d0e7d6860c6.csv: SUCCESS - 570 records for schedule 20250614_192306i48-866539488a7983338aa44d0e7d6860c6
# 2025-07-04 19:18:12,388 INFO:   20250614_192306i117-0abcfc3677ab4e0c5f7d69ed0aacf395.csv: SUCCESS - 570 records for schedule 20250614_192306i117-0abcfc3677ab4e0c5f7d69ed0aacf395
# 2025-07-04 19:18:12,388 INFO:   20250614_192306i45-c26157a0370bf55f16c21cb3aa1bce50.csv: SUCCESS - 570 records for schedule 20250614_192306i45-c26157a0370bf55f16c21cb3aa1bce50
# 2025-07-04 19:18:12,388 INFO:   20250614_192306i103-a9a3d8aff8b4a6731f316c1434d654ad.csv: SUCCESS - 570 records for schedule 20250614_192306i103-a9a3d8aff8b4a6731f316c1434d654ad
# 2025-07-04 19:18:12,388 INFO:   20250614_192306i110-ef01b8542d450cae83b47e0a2ccb8234.csv: SUCCESS - 570 records for schedule 20250614_192306i110-ef01b8542d450cae83b47e0a2ccb8234
# 2025-07-04 19:18:12,389 INFO:   20250614_192306i53-44ec4ed699776ec5c581e36885cc4f5e.csv: SUCCESS - 570 records for schedule 20250614_192306i53-44ec4ed699776ec5c581e36885cc4f5e
# 2025-07-04 19:18:12,389 INFO:   20250614_192306i34-659c3e528400cca081d28a50c2595262.csv: SUCCESS - 570 records for schedule 20250614_192306i34-659c3e528400cca081d28a50c2595262
# 2025-07-04 19:18:12,389 INFO:   20250614_192306i135-7b8a23bc842587ad96b5475acb95963f.csv: SUCCESS - 570 records for schedule 20250614_192306i135-7b8a23bc842587ad96b5475acb95963f
# 2025-07-04 19:18:12,389 INFO:   20250614_192306i37-c261c9a2bd9ce1a913993701a59ba2f4.csv: SUCCESS - 570 records for schedule 20250614_192306i37-c261c9a2bd9ce1a913993701a59ba2f4
# 2025-07-04 19:18:12,390 INFO:   20250614_192306i46-4c1c1dd66b9ffacb1c5605205eac415f.csv: SUCCESS - 570 records for schedule 20250614_192306i46-4c1c1dd66b9ffacb1c5605205eac415f
# 2025-07-04 19:18:12,390 INFO:   20250614_192306i145-5f135c01d691c011f68f94ae3bd40e7f.csv: SUCCESS - 570 records for schedule 20250614_192306i145-5f135c01d691c011f68f94ae3bd40e7f
# 2025-07-04 19:18:12,390 WARNING:   20250614_190410i3-3cf27d5eb733b50555b86a12b1c95554.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,390 INFO:   20250614_192306i177-c5904b582b6ce41608d000405af521a6.csv: SUCCESS - 570 records for schedule 20250614_192306i177-c5904b582b6ce41608d000405af521a6
# 2025-07-04 19:18:12,391 INFO:   20250614_192306i185-e81fa457ee0762603f3ee736a44a9042.csv: SUCCESS - 570 records for schedule 20250614_192306i185-e81fa457ee0762603f3ee736a44a9042
# 2025-07-04 19:18:12,391 INFO:   20250614_192306i146-9aa91940b27e721391777b9d75b7f128.csv: SUCCESS - 570 records for schedule 20250614_192306i146-9aa91940b27e721391777b9d75b7f128
# 2025-07-04 19:18:12,391 INFO:   20250614_192306i91-32f64d4a7b208aa752c29c96042ba25a.csv: SUCCESS - 570 records for schedule 20250614_192306i91-32f64d4a7b208aa752c29c96042ba25a
# 2025-07-04 19:18:12,392 INFO:   20250614_192306i62-05476a94fded0a4e1560ade157643546.csv: SUCCESS - 570 records for schedule 20250614_192306i62-05476a94fded0a4e1560ade157643546
# 2025-07-04 19:18:12,392 INFO:   20250614_192306i57-b5e4f9b351581bd6c2b4dc610ff79907.csv: SUCCESS - 570 records for schedule 20250614_192306i57-b5e4f9b351581bd6c2b4dc610ff79907
# 2025-07-04 19:18:12,392 INFO:   20250614_075849i31-d7906195d286b6c58c77960a4b8ca1a5.csv: SUCCESS - 570 records for schedule 20250614_075849i31-d7906195d286b6c58c77960a4b8ca1a5
# 2025-07-04 19:18:12,393 INFO:   20250614_075849i20-6dfd8e5e7682022250b3720330ad07e1.csv: SUCCESS - 570 records for schedule 20250614_075849i20-6dfd8e5e7682022250b3720330ad07e1
# 2025-07-04 19:18:12,393 INFO:   20250614_192306i74-7ab4339fe01be34123334b3c4462a603.csv: SUCCESS - 570 records for schedule 20250614_192306i74-7ab4339fe01be34123334b3c4462a603
# 2025-07-04 19:18:12,393 INFO:   20250614_192306i108-c938a04289ca5a78fe7a20af8310f8ce.csv: SUCCESS - 570 records for schedule 20250614_192306i108-c938a04289ca5a78fe7a20af8310f8ce
# 2025-07-04 19:18:12,393 INFO:   20250614_192306i98-289bb3dea7554bf43613514ca6337ae4.csv: SUCCESS - 570 records for schedule 20250614_192306i98-289bb3dea7554bf43613514ca6337ae4
# 2025-07-04 19:18:12,394 INFO:   20250614_192306i101-f9a355c91a0e5fe3d1f71ca40d38d9f8.csv: SUCCESS - 570 records for schedule 20250614_192306i101-f9a355c91a0e5fe3d1f71ca40d38d9f8
# 2025-07-04 19:18:12,394 WARNING:   20250614_191208i1-24b4560d1a0be528d3e6e42ac53c3608.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,394 INFO:   20250614_192306i157-f8b60a6e93b8b2b9f70c7c798d28397f.csv: SUCCESS - 570 records for schedule 20250614_192306i157-f8b60a6e93b8b2b9f70c7c798d28397f
# 2025-07-04 19:18:12,394 INFO:   20250614_192306i139-c97b2ce9656246158df0a4dcc6f16719.csv: SUCCESS - 570 records for schedule 20250614_192306i139-c97b2ce9656246158df0a4dcc6f16719
# 2025-07-04 19:18:12,394 INFO:   20250614_192306i26-e7e302df1c786c5ac7a2a82fca775a3a.csv: SUCCESS - 570 records for schedule 20250614_192306i26-e7e302df1c786c5ac7a2a82fca775a3a
# 2025-07-04 19:18:12,395 INFO:   20250614_192306i173-580226d57efc46aba3962bdaa5bd5703.csv: SUCCESS - 570 records for schedule 20250614_192306i173-580226d57efc46aba3962bdaa5bd5703
# 2025-07-04 19:18:12,395 INFO:   20250614_192306i137-3bd8123e24e22959783c46aa858cf9b0.csv: SUCCESS - 570 records for schedule 20250614_192306i137-3bd8123e24e22959783c46aa858cf9b0
# 2025-07-04 19:18:12,395 INFO:   20250614_192306i94-387eb5c7749bc6520a0ae82f6bcec62b.csv: SUCCESS - 570 records for schedule 20250614_192306i94-387eb5c7749bc6520a0ae82f6bcec62b
# 2025-07-04 19:18:12,396 INFO:   20250614_075849i24-e57f5d4d98d9fc50ca5ccdac55e579a7.csv: SUCCESS - 570 records for schedule 20250614_075849i24-e57f5d4d98d9fc50ca5ccdac55e579a7
# 2025-07-04 19:18:12,396 INFO:   20250614_192306i67-854e6ee3a829681fc5eb1db51c640d14.csv: SUCCESS - 570 records for schedule 20250614_192306i67-854e6ee3a829681fc5eb1db51c640d14
# 2025-07-04 19:18:12,396 INFO:   20250614_192306i132-92d9d9ba4681701e22d8dce14a7b4601.csv: SUCCESS - 570 records for schedule 20250614_192306i132-92d9d9ba4681701e22d8dce14a7b4601
# 2025-07-04 19:18:12,396 INFO:   20250614_192306i144-0f46a612719893bdabbd45e1e5a7c136.csv: SUCCESS - 570 records for schedule 20250614_192306i144-0f46a612719893bdabbd45e1e5a7c136
# 2025-07-04 19:18:12,397 INFO:   20250614_192306i123-c1bd861e87da04ea78153f1d69bf7e7a.csv: SUCCESS - 570 records for schedule 20250614_192306i123-c1bd861e87da04ea78153f1d69bf7e7a
# 2025-07-04 19:18:12,397 INFO:   20250614_192306i69-a1e479c271b33bc2e62f458700baa7bc.csv: SUCCESS - 570 records for schedule 20250614_192306i69-a1e479c271b33bc2e62f458700baa7bc
# 2025-07-04 19:18:12,397 INFO:   20250614_192306i133-078bd26ea665e57aff6caafcbbfa817f.csv: SUCCESS - 570 records for schedule 20250614_192306i133-078bd26ea665e57aff6caafcbbfa817f
# 2025-07-04 19:18:12,397 WARNING:   20250614_192306i187-c5dd16e87d3b3052ca9eefac51645f3c.csv: ERROR - Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,398 INFO:   20250614_192306i184-d105ee5f588f19cdbdb6bf810c389387.csv: SUCCESS - 570 records for schedule 20250614_192306i184-d105ee5f588f19cdbdb6bf810c389387
# 2025-07-04 19:18:12,398 INFO:   20250614_075849i21-24044409e5260cb31725084d9bf13530.csv: SUCCESS - 570 records for schedule 20250614_075849i21-24044409e5260cb31725084d9bf13530
# 2025-07-04 19:18:12,398 INFO:   20250614_192306i3-b4f27335b3248e6017fb6eb48d7871f8.csv: SUCCESS - 570 records for schedule 20250614_192306i3-b4f27335b3248e6017fb6eb48d7871f8
# 2025-07-04 19:18:12,399 INFO:   20250614_192306i41-d35efdd8060dfb88a9e4f1150394df55.csv: SUCCESS - 570 records for schedule 20250614_192306i41-d35efdd8060dfb88a9e4f1150394df55
# 2025-07-04 19:18:12,403 INFO: Successfully processed 234 files, 120840 total records
# 2025-07-04 19:18:12,404 WARNING: Some files had errors:
# 2025-07-04 19:18:12,405 WARNING:   20250614_181924i1-942856b0e73d31921e4355bf54b03c4b.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,405 WARNING:   20250614_191208i5-43ce82620e8d98825f18995c5cbbbfa1.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,406 WARNING:   20250614_190410i2-e3326eb13e1b2912f3ff4581e84cb669.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,406 WARNING:   20250614_181924i5-81500d4605d7b6bd308980da6922a21a.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,406 WARNING:   20250614_181924i3-030ab17aaa57d078fabb7e53d71cd970.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,408 WARNING:   20250614_190340i4-beb83867db139191ee0c774e5fa1fe64.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,408 WARNING:   20250614_190340i5-ed7e2e794ef6b9ceddd074734d559edf.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,411 WARNING:   20250614_190340i3-d5597ce8e03a770be9a16426b577787a.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,412 WARNING:   20250614_190340i1-7a8baa681c486f27730787b45eeabbad.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,414 WARNING:   20250614_190340i2-9411e19df08fe87fd0e06d2c4e0f2519.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,415 WARNING:   20250614_190410i5-8cdfd70678853f257c9985097b5b677e.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,416 WARNING:   20250614_191208i2-ad7a48a504419455eeb5e262cfea1ff8.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,417 WARNING:   20250614_191208i3-b8ebea855401b919cca763bbfa3e049b.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,418 WARNING:   20250614_190410i4-91baa9b3e5235f094d54f9a674abf525.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,418 WARNING:   20250614_181924i2-24f65e9dc3eeeaa86989220b5d34ac1f.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,419 WARNING:   20250614_191208i4-5713d82185c46333a71011fd97b31163.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,420 WARNING:   20250614_190410i1-f53c66fa53b8ff8b2912535bc1f5c965.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,421 WARNING:   20250614_190343i1-deaf561e13e5576a366dfced9666dc37.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,422 WARNING:   20250614_181924i4-d97eb563a84b570bd9b5a3fd062a3903.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,422 WARNING:   20250614_190410i3-3cf27d5eb733b50555b86a12b1c95554.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,423 WARNING:   20250614_191208i1-24b4560d1a0be528d3e6e42ac53c3608.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,424 WARNING:   20250614_192306i187-c5dd16e87d3b3052ca9eefac51645f3c.csv: Required columns not found. Available: ['', 'block', 'slot']
# 2025-07-04 19:18:12,425 INFO: Schedule upload process completed successfully

# %%
# Out:
# 2025-07-04 20:07:56,396 INFO: Found 214 CSV files to upload
# ['../results/sp25/metrics/20250614_192306i29-b841f75cc2ece8aa01303e36f22146b7.csv',
#  '../results/sp25/metrics/20250614_075849i32-53cb986b35a7d9441e28cddd65901951.csv',
#  '../results/sp25/metrics/20250614_192306i183-098df1d9bd308e5472d31178e543d735.csv',
#  '../results/sp25/metrics/20250614_192306i99-52b5b4fad2a7ae28425bc942d6e3ad86.csv',
#  '../results/sp25/metrics/20250614_192306i153-aba07d40b571cd0947cdb7f0e79ed26a.csv',
#  '../results/sp25/metrics/20250614_075849i37-b9b1e8e4d86b12116402c53de6c33c2b.csv',
#  '../results/sp25/metrics/20250614_192306i119-a0820601e913ecd013f07d57c77640be.csv',
#  '../results/sp25/metrics/20250614_192306i114-27199c46d176e9419702bb9522f617fa.csv',
#  '../results/sp25/metrics/20250614_192306i140-9013cd903892a340caa5a43c2972fac9.csv',
#  '../results/sp25/metrics/20250614_192306i161-30a1577607ba378054af5a9db9cb07b3.csv',
#  '../results/sp25/metrics/20250614_192306i24-6c0ed36d9503ed9193b727059a1fca4d.csv',
#  '../results/sp25/metrics/20250614_192306i9-fc285d76cc39ba548e4ff3963e753b88.csv',
#  '../results/sp25/metrics/20250614_192306i77-8c0f2373e9d01156e1f59e24ae6483d8.csv',
#  '../results/sp25/metrics/20250614_192306i14-ae3053e740347978092f3dba5b0f2414.csv',
#  '../results/sp25/metrics/20250614_192306i151-145c71226b10591be810bd62f290c9a0.csv',
#  '../results/sp25/metrics/20250614_192306i163-3f70dd47af632bc2dfd3435ef5c3f8b2.csv',
#  '../results/sp25/metrics/20250614_192306i28-f77ab74e1350742aa2bf461c7028ffbe.csv',
#  '../results/sp25/metrics/20250614_192306i138-111a564af814066182e97cb7b82c1e26.csv',
#  '../results/sp25/metrics/20250614_192306i115-bcfdce8ee96e378c3123451962da98be.csv',
#  '../results/sp25/metrics/20250614_192306i32-699ba935ce96b374aa71f33694d16136.csv',
#  '../results/sp25/metrics/20250614_192306i171-59643d4676349fc7cd3095f69c5664ee.csv',
#  '../results/sp25/metrics/20250614_192306i43-fe6f51cb89f5b6fa929cf3ab2fc465de.csv',
#  '../results/sp25/metrics/20250614_192306i44-121c7cfecce35b7c9979f1c50ed669e6.csv',
#  '../results/sp25/metrics/20250614_192306i20-8dd548d6fc7c6482274eeb4b4821b9b8.csv',
#  '../results/sp25/metrics/20250614_192306i65-d5bdff11ed806fe6785614d8f4505b69.csv',
#  '../results/sp25/metrics/20250614_192306i30-812b144b141744107638e089258e4d93.csv',
#  '../results/sp25/metrics/20250614_075849i34-fe7961170e44b1aa7a71324734ddb0b1.csv',
#  '../results/sp25/metrics/20250614_192306i128-b2d966749f7e025f00f982bf8a51a3c6.csv',
#  '../results/sp25/metrics/20250614_192306i105-0af5f99baafa362c37c6604afcf887c1.csv',
#  '../results/sp25/metrics/20250614_192306i21-dc800016dd0a34c5e55feabba7fa9133.csv',
#  '../results/sp25/metrics/20250614_192306i66-2e2d714071a28cc4c6aed197a1e683ad.csv',
#  '../results/sp25/metrics/20250614_192306i64-ac29d2644da4ee812c020dd5713549de.csv',
#  '../results/sp25/metrics/20250614_192306i61-cfc6bb008f4e4db799da498531f2295b.csv',
#  '../results/sp25/metrics/20250614_192306i142-3ca08dc755fe6826e69bfeecba9cfaf6.csv',
#  '../results/sp25/metrics/20250614_192306i158-456324681a0426d819d6f15d5e3bbec2.csv',
#  '../results/sp25/metrics/20250614_192306i11-643dc5082d668033d7c4ebd4af4ba363.csv',
#  '../results/sp25/metrics/20250614_192306i189-da9337b09e662ebfd15a5deb35030e5e.csv',
#  '../results/sp25/metrics/20250614_075849i19-fe52c298959434605e7d02f6ce94ebf0.csv',
#  '../results/sp25/metrics/20250614_192306i107-49b175997bcee4b2332ae4b81e779210.csv',
#  '../results/sp25/metrics/20250614_075849i18-7250af83cc5000f6b43fad4d17b9ec48.csv',
#  '../results/sp25/metrics/20250614_192306i159-0e6b71743e093b2fd2021fb71b5a2755.csv',
#  '../results/sp25/metrics/20250614_192306i141-77ea3ba4eb69aa183a1ad317005d318d.csv',
#  '../results/sp25/metrics/20250614_192306i15-8eb0db5f57decf179479e5c8be013381.csv',
#  '../results/sp25/metrics/20250614_192306i68-e243035c3158a906a77896ba71ce78fc.csv',
#  '../results/sp25/metrics/20250614_192306i113-ca404054c80c4c2bbae96abf718ad802.csv',
#  '../results/sp25/metrics/20250614_192306i88-961be3183a44e926c324162558ff9418.csv',
#  '../results/sp25/metrics/20250614_075849i36-8173c74a9381334bc1acc52a40577c34.csv',
#  '../results/sp25/metrics/20250614_192306i155-90cfe2fed13e5f0a5354f7afbab1f81d.csv',
#  '../results/sp25/metrics/20250614_075849i39-d08dbb9ebcbdecf83617e81cc86a7fe8.csv',
#  '../results/sp25/metrics/20250614_192306i70-16f6e9202bd48632144f0e19cb488162.csv',
#  '../results/sp25/metrics/20250614_192306i122-4e7f9bb88aab2d81a996fa245c22294b.csv',
#  '../results/sp25/metrics/20250614_192306i38-3e84957e52fba0be95c87200f8f590dc.csv',
#  '../results/sp25/metrics/20250614_192306i136-dc448e95cfab126b9c1355615d4a5863.csv',
#  '../results/sp25/metrics/20250614_192306i156-67bd7d5ee5d4387f7c968f4dd54f415a.csv',
#  '../results/sp25/metrics/20250614_192306i150-df6c29c5f62d37ed97aab7ec3bb7333d.csv',
#  '../results/sp25/metrics/20250614_192306i31-1342ca27cc5159c4ab46907848b60f5f.csv',
#  '../results/sp25/metrics/20250614_192306i182-f46888bb5ded4e10d4ff1618710f09b4.csv',
#  '../results/sp25/metrics/20250614_192306i147-f92bbe50c1a7ddc36225973544d24255.csv',
#  '../results/sp25/metrics/20250614_192306i76-eca4e070785088464361f6f06fe7807e.csv',
#  '../results/sp25/metrics/20250614_192306i75-1e01350f9105362cdf4eb38cbc3bf2e5.csv',
#  '../results/sp25/metrics/20250614_075849i16-14a6536953d30f5ef1460dda258b7e3b.csv',
#  '../results/sp25/metrics/20250614_075849i38-1c46b69b23456c06e3c3e52e71a816f6.csv',
#  '../results/sp25/metrics/20250614_192306i93-e03b880e5a9410ed6da6eab9d45bd732.csv',
#  '../results/sp25/metrics/20250614_192306i100-e86418b6bbbfeef352d8c18a586ed911.csv',
#  '../results/sp25/metrics/20250614_192306i18-749aa50d0e3fb840113d3bdae7165a47.csv',
#  '../results/sp25/metrics/20250614_192306i47-75387112fef49795e951c4202979052b.csv',
#  '../results/sp25/metrics/20250614_192306i50-01510e3817398aef28a46fa260b0696a.csv',
#  '../results/sp25/metrics/20250614_192306i96-f06ad7fa3d0e7398bbd896649ecb6738.csv',
#  '../results/sp25/metrics/20250614_192306i109-b0afa3913077b42ea731b8bb2a0832b0.csv',
#  '../results/sp25/metrics/20250614_075849i30-1cf8b57cb495ea11f1e221404fa9410e.csv',
#  '../results/sp25/metrics/20250614_192306i86-9d6405573bd06ca54b1449ec26fd9bae.csv',
#  '../results/sp25/metrics/20250614_192306i25-70789b1153229aea0b165361fe105e77.csv',
#  '../results/sp25/metrics/20250614_192306i60-c086bde7c5b4e6a74b0b312e80affd41.csv',
#  '../results/sp25/metrics/20250614_192306i102-0f783b7886060f3822c0cdad0854616d.csv',
#  '../results/sp25/metrics/20250614_192306i169-5b06fb3a57180d7c783d79d52a86500f.csv',
#  '../results/sp25/metrics/20250614_192306i7-7bfc522e853539eb4cbe7696ab10be51.csv',
#  '../results/sp25/metrics/20250614_192306i85-ae7bd6aa6cdcf62488bd4a04cd18bcef.csv',
#  '../results/sp25/metrics/20250614_075849i23-d6b347f98b27b330e4b6976e790998ba.csv',
#  '../results/sp25/metrics/20250614_192306i104-22819fea22eb362c232709b5c7187e4a.csv',
#  '../results/sp25/metrics/20250614_192306i17-110edb7cdcedd48f5bf023f031f02708.csv',
#  '../results/sp25/metrics/20250614_192306i127-9644d2e2e75af6ec8194f772b2d45083.csv',
#  '../results/sp25/metrics/20250614_192306i40-849f406a55945ca366ccf7a19af7f301.csv',
#  '../results/sp25/metrics/20250614_192306i12-8cfcc46f3e97dd5ee14ea433701f75fd.csv',
#  '../results/sp25/metrics/20250614_192306i124-f4a145a8d89166236243089de5ebc9dc.csv',
#  '../results/sp25/metrics/20250614_075849i40-753c89e22723bc11a626cf6d10f7ad92.csv',
#  '../results/sp25/metrics/20250614_192306i51-455ccca9505a20cf8044204b7a169f96.csv',
#  '../results/sp25/metrics/20250614_192306i167-b04cea0748b055a2ff3f3303b6c579a6.csv',
#  '../results/sp25/metrics/20250614_192306i82-006d6106a164801d6c072e9f458a6028.csv',
#  '../results/sp25/metrics/20250614_192306i134-7626e0f73d8379638c29ef2c7e0aea2b.csv',
#  '../results/sp25/metrics/20250614_192306i39-c4c98088c07559e10f1331da0c229079.csv',
#  '../results/sp25/metrics/20250614_192306i84-d6eaa0d726406daece035ba3ddded8a1.csv',
#  '../results/sp25/metrics/20250614_075849i26-878b4c69f6a55d1d46b3d04f67110e57.csv',
#  '../results/sp25/metrics/20250614_192306i54-b960cfdf9a4c00c231be66609de6545b.csv',
#  '../results/sp25/metrics/20250614_192306i55-64eefbb279df0577700cbfa3a7a2fb89.csv',
#  '../results/sp25/metrics/20250614_192306i4-d8725c9c5482fccf1e186c93284d17b6.csv',
#  '../results/sp25/metrics/20250614_192306i56-1d19b3762902f9cc3730a2d1eabffe3b.csv',
#  '../results/sp25/metrics/20250614_192306i143-8a4d218375e2e787fdd2c94f816edb40.csv',
#  '../results/sp25/metrics/20250614_192306i2-a97419ede372d644c04aefa813a71c74.csv',
#  '../results/sp25/metrics/20250614_192306i175-a604daff68cefb9873ce6c30e87cc480.csv',
#  '../results/sp25/metrics/20250614_192306i90-d6897b399519944ed8ee4a724ff536ad.csv',
#  '../results/sp25/metrics/20250614_075849i17-07c1164f7a34b88911ac8c212c07e0a4.csv',
#  '../results/sp25/metrics/20250614_192306i168-c5df3863f00ebed21232485cc6e7b9f1.csv',
#  '../results/sp25/metrics/20250614_192306i178-71045229ed8769f036b9c7554e3eb28b.csv',
#  '../results/sp25/metrics/20250614_192306i83-97f2593c409dd0f8dc20b8d4ddecf378.csv',
#  '../results/sp25/metrics/20250614_192306i6-543aa96d2801f8bad578af1a592d1e52.csv',
#  '../results/sp25/metrics/20250614_192306i58-6989a8de2bb881b17fbc4ec3d14a61a4.csv',
#  '../results/sp25/metrics/20250614_192306i152-23a1a38f170f5c1763f90367abfc5767.csv',
#  '../results/sp25/metrics/20250614_192306i170-19108ac3facb08bac8366e746178a0e6.csv',
#  '../results/sp25/metrics/20250614_192306i73-2e24d719152fb232781e6600cf7894fb.csv',
#  '../results/sp25/metrics/20250614_192306i95-f87a6aa5781164ae48ea621dcfa2205a.csv',
#  '../results/sp25/metrics/20250614_075849i33-f11a906957dd565d45188aaca066c45c.csv',
#  '../results/sp25/metrics/20250614_192306i121-9b5199edbce0d236f0ca012c033888b9.csv',
#  '../results/sp25/metrics/20250614_192306i179-4e4997b086a8f5a7abac0d8b9e159ce8.csv',
#  '../results/sp25/metrics/20250614_075849i25-78321219bd0279c1312ab6ed29bca4db.csv',
#  '../results/sp25/metrics/20250614_075849i35-bb9ca99e65f20d23e7242bd9ff5ca218.csv',
#  '../results/sp25/metrics/20250614_075849i29-aad821a31c678b3ab8284e63c8145f73.csv',
#  '../results/sp25/metrics/20250614_192306i120-223100d0736a22819c2b817b815d5845.csv',
#  '../results/sp25/metrics/20250614_192306i131-749b10bf696b2f821c0091bc1e68e1fa.csv',
#  '../results/sp25/metrics/20250614_192306i125-00327be486b458c6e6512b12e4897e7b.csv',
#  '../results/sp25/metrics/20250614_192306i36-e7dee4b0cc8e8afefe0e4ed4a6313ca0.csv',
#  '../results/sp25/metrics/20250614_192306i148-a2d4275bf4d00323740c4381ddf5f890.csv',
#  '../results/sp25/metrics/20250614_075849i28-4ebd99276c7d36e3a666eb087e541fa7.csv',
#  '../results/sp25/metrics/20250614_192306i79-d4170d24c1ea4cf6b4d7aa75d7bde4f8.csv',
#  '../results/sp25/metrics/20250614_192306i166-7089a0c1ab69d0adfd64285cc95bd48a.csv',
#  '../results/sp25/metrics/20250614_192306i1-88c271c6ac8f16680c7760ce37737662.csv',
#  '../results/sp25/metrics/20250614_192306i154-e4e06274bc27307167dd782810e2011a.csv',
#  '../results/sp25/metrics/20250614_192306i81-d70ae3a0c95f83b7889fc75d2e316577.csv',
#  '../results/sp25/metrics/20250614_192306i97-d060a30596adf990e7d62d7a79ed0766.csv',
#  '../results/sp25/metrics/20250614_192306i112-7d3bcd9c847bb4ea4d1144e5db8adf7b.csv',
#  '../results/sp25/metrics/20250614_192306i188-41782849568a18c8c6a4b65e72ea095f.csv',
#  '../results/sp25/metrics/20250614_192306i22-b7d3e8aaaed636ffb5ec59c34c98ac7b.csv',
#  '../results/sp25/metrics/20250614_192306i71-36413d79ba463bd85a0f50bb90023654.csv',
#  '../results/sp25/metrics/20250614_192306i10-efc12cc4e9eee4924080103ffb8cb3ff.csv',
#  '../results/sp25/metrics/20250614_192306i176-6c189e25bacce3d60d040b2ff38cb8bc.csv',
#  '../results/sp25/metrics/20250614_192306i116-6f275568900b37713152bc105f37c5af.csv',
#  '../results/sp25/metrics/20250614_192306i172-7335a8275a3498e03ee9929864de0d62.csv',
#  '../results/sp25/metrics/20250614_192306i23-dadb513c68410627968d932edeecb95a.csv',
#  '../results/sp25/metrics/20250614_192306i8-303945b9229833556b70a881055cdea7.csv',
#  '../results/sp25/metrics/20250614_192306i49-4a7a3bf549c0dda5da161e14ee1b33fa.csv',
#  '../results/sp25/metrics/20250614_192306i27-ccedb2aea227ee7c839d429ffb307090.csv',
#  '../results/sp25/metrics/20250614_192306i80-ef673b4d340cabbb753ce67c25c24905.csv',
#  '../results/sp25/metrics/20250614_192306i181-ed67f247e2034a2abd5face20deff289.csv',
#  '../results/sp25/metrics/20250614_192306i78-2daada8cf9f92d5dd5b8b5c427a51a53.csv',
#  '../results/sp25/metrics/20250614_192306i186-a8305d458c1f483fd70f8ae8d12d7108.csv',
#  '../results/sp25/metrics/20250614_192306i149-17548a40f9b10699f124814d5a482e1c.csv',
#  '../results/sp25/metrics/20250614_192306i92-e4b7683bdca8a06bf190e52e879dc05a.csv',
#  '../results/sp25/metrics/20250614_192306i174-2a535729146411992975153baaa54d46.csv',
#  '../results/sp25/metrics/20250614_192306i72-b7e246e8befc47a481b1ad5059c30836.csv',
#  '../results/sp25/metrics/20250614_192306i190-2b62f0c27278d38b0155846365c8a0a9.csv',
#  '../results/sp25/metrics/20250614_192306i111-e32a202837daeb512019da8f3d267f0f.csv',
#  '../results/sp25/metrics/20250614_075849i22-38575f29a261b426b9a9524c8c2ae2b3.csv',
#  '../results/sp25/metrics/20250614_192306i126-b7aeadbbdfffc3823ce568289f230c60.csv',
#  '../results/sp25/metrics/20250614_192306i89-938ec509c131b1acc8cf709266e3d523.csv',
#  '../results/sp25/metrics/20250614_192306i160-fab900bedfa78e978dae14bb34ffcc53.csv',
#  '../results/sp25/metrics/20250614_192306i13-229d84294299373563cfad5582e6573c.csv',
#  '../results/sp25/metrics/20250614_192306i33-179366c32a03c5e0be748b969662a899.csv',
#  '../results/sp25/metrics/20250614_192306i59-5d5cda608f3c7d976b26d60df42b4989.csv',
#  '../results/sp25/metrics/20250614_192306i63-dd50bc491cdb93c600279d4540a95410.csv',
#  '../results/sp25/metrics/20250614_192306i106-bc0133bcd255bdbb9b0f4327c8b503fd.csv',
#  '../results/sp25/metrics/20250614_192306i5-9738bd25fa2cedc980a512f9f36ee27b.csv',
#  '../results/sp25/metrics/20250614_192306i162-a7485925069e27cbfea9fd6ef185961c.csv',
#  '../results/sp25/metrics/20250614_192306i52-1530dc9668e003b01f70b946fdf041fe.csv',
#  '../results/sp25/metrics/20250614_192306i130-817006358a73a1a35d995fd509919a31.csv',
#  '../results/sp25/metrics/20250614_075849i27-96095a9951ca69608779c1237024d392.csv',
#  '../results/sp25/metrics/20250614_192306i42-f6564b471241b94acb3d4a2aad77eb43.csv',
#  '../results/sp25/metrics/20250614_192306i19-14d2e5cb0c12447989f58819cc3fd3d3.csv',
#  '../results/sp25/metrics/20250614_192306i129-94835b0c77ca746b11accf533359fa47.csv',
#  '../results/sp25/metrics/20250614_192306i118-1f720e92fda517c64d9fa27f446ab6c0.csv',
#  '../results/sp25/metrics/20250614_192306i165-60ef9d6996ad6eab0689d3f6a6634924.csv',
#  '../results/sp25/metrics/20250614_192306i16-b414852a375a9d723e56d968b43c7da8.csv',
#  '../results/sp25/metrics/20250614_192306i164-5bf1347002c8e7ac577afdce6b64fac0.csv',
#  '../results/sp25/metrics/20250614_192306i87-898f94291d22c10ee1b763b5404085b2.csv',
#  '../results/sp25/metrics/20250614_192306i180-a2d72619e029186d246494e21c9348de.csv',
#  '../results/sp25/metrics/20250614_192306i35-8ae1f1c2b8dcc1b86846d1d1a5c21371.csv',
#  '../results/sp25/metrics/20250614_192306i48-866539488a7983338aa44d0e7d6860c6.csv',
#  '../results/sp25/metrics/20250614_192306i117-0abcfc3677ab4e0c5f7d69ed0aacf395.csv',
#  '../results/sp25/metrics/20250614_192306i45-c26157a0370bf55f16c21cb3aa1bce50.csv',
#  '../results/sp25/metrics/20250614_192306i103-a9a3d8aff8b4a6731f316c1434d654ad.csv',
#  '../results/sp25/metrics/20250614_192306i110-ef01b8542d450cae83b47e0a2ccb8234.csv',
#  '../results/sp25/metrics/20250614_192306i53-44ec4ed699776ec5c581e36885cc4f5e.csv',
#  '../results/sp25/metrics/20250614_192306i34-659c3e528400cca081d28a50c2595262.csv',
#  '../results/sp25/metrics/20250614_192306i135-7b8a23bc842587ad96b5475acb95963f.csv',
#  '../results/sp25/metrics/20250614_192306i37-c261c9a2bd9ce1a913993701a59ba2f4.csv',
#  '../results/sp25/metrics/20250614_192306i46-4c1c1dd66b9ffacb1c5605205eac415f.csv',
#  '../results/sp25/metrics/20250614_192306i145-5f135c01d691c011f68f94ae3bd40e7f.csv',
#  '../results/sp25/metrics/20250614_192306i177-c5904b582b6ce41608d000405af521a6.csv',
#  '../results/sp25/metrics/20250614_192306i185-e81fa457ee0762603f3ee736a44a9042.csv',
#  '../results/sp25/metrics/20250614_192306i146-9aa91940b27e721391777b9d75b7f128.csv',
#  '../results/sp25/metrics/20250614_192306i91-32f64d4a7b208aa752c29c96042ba25a.csv',
#  '../results/sp25/metrics/20250614_192306i62-05476a94fded0a4e1560ade157643546.csv',
#  '../results/sp25/metrics/20250614_192306i57-b5e4f9b351581bd6c2b4dc610ff79907.csv',
#  '../results/sp25/metrics/20250614_075849i31-d7906195d286b6c58c77960a4b8ca1a5.csv',
#  '../results/sp25/metrics/20250614_075849i20-6dfd8e5e7682022250b3720330ad07e1.csv',
#  '../results/sp25/metrics/20250614_192306i74-7ab4339fe01be34123334b3c4462a603.csv',
#  '../results/sp25/metrics/20250614_192306i108-c938a04289ca5a78fe7a20af8310f8ce.csv',
#  '../results/sp25/metrics/20250614_192306i98-289bb3dea7554bf43613514ca6337ae4.csv',
#  '../results/sp25/metrics/20250614_192306i101-f9a355c91a0e5fe3d1f71ca40d38d9f8.csv',
#  '../results/sp25/metrics/20250614_192306i157-f8b60a6e93b8b2b9f70c7c798d28397f.csv',
#  '../results/sp25/metrics/20250614_192306i139-c97b2ce9656246158df0a4dcc6f16719.csv',
#  '../results/sp25/metrics/20250614_192306i26-e7e302df1c786c5ac7a2a82fca775a3a.csv',
#  '../results/sp25/metrics/20250614_192306i173-580226d57efc46aba3962bdaa5bd5703.csv',
#  '../results/sp25/metrics/20250614_192306i137-3bd8123e24e22959783c46aa858cf9b0.csv',
#  '../results/sp25/metrics/20250614_192306i94-387eb5c7749bc6520a0ae82f6bcec62b.csv',
#  '../results/sp25/metrics/20250614_075849i24-e57f5d4d98d9fc50ca5ccdac55e579a7.csv',
#  '../results/sp25/metrics/20250614_192306i67-854e6ee3a829681fc5eb1db51c640d14.csv',
#  '../results/sp25/metrics/20250614_192306i132-92d9d9ba4681701e22d8dce14a7b4601.csv',
#  '../results/sp25/metrics/20250614_192306i144-0f46a612719893bdabbd45e1e5a7c136.csv',
#  '../results/sp25/metrics/20250614_192306i123-c1bd861e87da04ea78153f1d69bf7e7a.csv',
#  '../results/sp25/metrics/20250614_192306i69-a1e479c271b33bc2e62f458700baa7bc.csv',
#  '../results/sp25/metrics/20250614_192306i133-078bd26ea665e57aff6caafcbbfa817f.csv',
#  '../results/sp25/metrics/20250614_192306i184-d105ee5f588f19cdbdb6bf810c389387.csv',
#  '../results/sp25/metrics/20250614_075849i21-24044409e5260cb31725084d9bf13530.csv',
#  '../results/sp25/metrics/20250614_192306i3-b4f27335b3248e6017fb6eb48d7871f8.csv',
#  '../results/sp25/metrics/20250614_192306i41-d35efdd8060dfb88a9e4f1150394df55.csv']

# %%
#!/usr/bin/env python3
"""
G2 Cluster script to upload image files to Flask API
Run this after your visualization/chart generation algorithms complete
"""
import requests
import os
import glob
import logging
from pathlib import Path
import time
from typing import List, Dict
import sys

# Configuration
API_BASE_URL = "http://localhost:8000"  # Uncomment for local testing
API_KEY = ''  # 'your-production-secret-key-here-change-this'
IMAGES_DIR = "/Users/adamshafikjovine/Documents/BOScheduling/metrics/plots"  # Directory where your image files are generated
SUBDIRECTORY = "plots"  # Optional subdirectory in static folder (e.g., "charts", "plots", "visualizations")
RETRY_ATTEMPTS = 3
RETRY_DELAY = 5  # seconds
BATCH_SIZE = 5  # Number of images to upload per request (to avoid timeouts)

# Supported image extensions
SUPPORTED_EXTENSIONS = {'.png', '.jpg', '.jpeg', '.gif', '.bmp', '.webp', '.tiff'}

# Setup logging
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s: %(message)s",
    handlers=[
        logging.FileHandler("upload_images.log"),
        logging.StreamHandler(sys.stdout),
    ],
)
logger = logging.getLogger(__name__)


def clean_filename(filename: str) -> str:
    """Clean filename by removing .csv and other unwanted parts"""
    
    # Remove .csv from filename (including .csv_dist -> _dist)
    if '.csv_dist.' in filename:
        # Handle case: file.csv_dist.png -> file_dist.png
        filename = filename.replace('.csv_dist.', '_dist.')
    elif '.csv.' in filename:
        # Handle case: file.csv.png -> file.png
        filename = filename.replace('.csv.', '.')
    
    # Additional cleanup options:
    # Remove hash patterns if desired (optional)
    # filename = re.sub(r'-[a-f0-9]{32}', '', filename)  # Remove MD5 hashes
    
    # Remove extra underscores or dashes (optional)
    # filename = re.sub(r'[-_]+', '_', filename)  # Replace multiple dashes/underscores with single underscore
    
    return filename


def find_image_files(directory: str) -> List[str]:
    """Find all image files in the images directory"""
    image_files = []
    
    # Search for all supported image extensions
    for ext in SUPPORTED_EXTENSIONS:
        pattern = os.path.join(directory, f"20250618*{ext}")
        files = glob.glob(pattern, recursive=False)
        logger.debug(f'Found files for {ext}: {len(files)}')
        image_files.extend(files)
        
        # Also check uppercase extensions
        pattern_upper = os.path.join(directory, f"*{ext.upper()}")
        files_upper = glob.glob(pattern_upper, recursive=False)
        image_files.extend(files_upper)

    # Remove duplicates and filter out unwanted files
    image_files = list(set(image_files))
    filtered_files = [
        f for f in image_files 
        if not any(exclude in os.path.basename(f).lower() 
                  for exclude in ["_temp", "_backup", "_test", "temp_", ".tmp"])
    ]

    logger.info(f"Found {len(filtered_files)} image files to upload")
    return sorted(filtered_files)


def upload_images_to_api(image_files: List[str], subdirectory: str = "") -> Dict:
    """Upload image files to the Flask API with cleaned filenames"""

    # Prepare files for upload
    files = []
    filename_mapping = {}  # Track original -> cleaned filename mapping
    
    try:
        for image_file in image_files:
            # Get original filename
            original_filename = os.path.basename(image_file)
            
            # Clean the filename
            clean_filename_str = clean_filename(original_filename)
            
            # Store mapping for logging
            filename_mapping[clean_filename_str] = original_filename
            
            # Determine MIME type based on extension
            ext = os.path.splitext(image_file)[1].lower()
            if ext in ['.jpg', '.jpeg']:
                mime_type = 'image/jpeg'
            elif ext == '.png':
                mime_type = 'image/png'
            elif ext == '.gif':
                mime_type = 'image/gif'
            elif ext == '.bmp':
                mime_type = 'image/bmp'
            elif ext == '.webp':
                mime_type = 'image/webp'
            elif ext == '.tiff':
                mime_type = 'image/tiff'
            else:
                mime_type = 'image/jpeg'  # default
            
            # Use cleaned filename for upload
            files.append(
                (
                    "files",
                    (clean_filename_str, open(image_file, "rb"), mime_type),
                )
            )
            
            # Log the filename change if it was modified
            if original_filename != clean_filename_str:
                logger.info(f"Filename cleaned: {original_filename} -> {clean_filename_str}")

        # Prepare headers and form data
        data = {}
        if subdirectory:
            data["subdirectory"] = subdirectory

        # Make the request
        logger.info(f"Uploading {len(image_files)} image files to {API_BASE_URL}/api/upload-images")
        if subdirectory:
            logger.info(f"Target subdirectory: static/{subdirectory}/")

        response = requests.post(
            f"{API_BASE_URL}/api/upload-images",
            files=files,
            data=data,
            timeout=300,  # 5 minute timeout for large files
        )

        # Parse response
        if response.status_code in [200, 207]:  # 207 = partial success
            result = response.json()
            logger.info(f"Image upload successful: {result.get('message', 'Success')}")
            
            # Log details about processed files
            for file_result in result.get('processed_files', []):
                filename = file_result.get('filename', 'Unknown')
                if file_result.get('error'):
                    logger.warning(f"  {filename}: ERROR - {file_result['error']}")
                else:
                    uploaded_filename = file_result.get('uploaded_filename', 'Unknown')
                    web_path = file_result.get('uploaded_path', 'Unknown')
                    size_mb = file_result.get('size_bytes', 0) / (1024 * 1024)
                    dimensions = f"{file_result.get('width', '?')}x{file_result.get('height', '?')}"
                    
                    # Show original filename in parentheses if it was changed
                    original = filename_mapping.get(filename, filename)
                    filename_display = f"{filename} (was: {original})" if original != filename else filename
                    
                    logger.info(f"  {filename_display}: SUCCESS - {uploaded_filename} ({dimensions}, {size_mb:.1f}MB)")
                    logger.info(f"    Web URL: {web_path}")
            
            return result
        else:
            logger.error(f"Image upload failed: {response.status_code} - {response.text}")
            return {"error": f"HTTP {response.status_code}: {response.text}"}

    except requests.exceptions.RequestException as e:
        logger.error(f"Network error during image upload: {e}")
        return {"error": f"Network error: {e}"}

    except Exception as e:
        logger.error(f"Unexpected error during image upload: {e}")
        return {"error": f"Unexpected error: {e}"}

    finally:
        # Close all file handles
        for _, file_tuple in files:
            if len(file_tuple) >= 2 and hasattr(file_tuple[1], "close"):
                file_tuple[1].close()


def upload_images_with_retry(image_files: List[str], subdirectory: str = "") -> bool:
    """Upload image files with retry logic"""

    for attempt in range(1, RETRY_ATTEMPTS + 1):
        logger.info(f"Image upload attempt {attempt}/{RETRY_ATTEMPTS}")

        result = upload_images_to_api(image_files, subdirectory)

        if "error" not in result:
            # Success
            processed_files = result.get("processed_files", [])
            total_size_mb = result.get("total_size_bytes", 0) / (1024 * 1024)

            logger.info(f"Successfully processed {len(processed_files)} files, {total_size_mb:.1f}MB total")

            # Check for any file-level errors
            file_errors = [f for f in processed_files if f.get('error')]
            if file_errors:
                logger.warning(f"Some files had errors:")
                for error_file in file_errors:
                    logger.warning(f"  {error_file['filename']}: {error_file['error']}")

            return True
        else:
            # Error occurred
            logger.error(f"Attempt {attempt} failed: {result['error']}")

            if attempt < RETRY_ATTEMPTS:
                logger.info(f"Retrying in {RETRY_DELAY} seconds...")
                time.sleep(RETRY_DELAY)

    logger.error(f"All {RETRY_ATTEMPTS} attempts failed")
    return False


def upload_in_batches(image_files: List[str], subdirectory: str = "") -> bool:
    """Upload image files in batches to avoid timeouts"""
    
    total_files = len(image_files)
    successful_batches = 0
    total_batches = (total_files + BATCH_SIZE - 1) // BATCH_SIZE  # Ceiling division
    
    logger.info(f"Uploading {total_files} files in {total_batches} batches of {BATCH_SIZE}")
    
    for i in range(0, total_files, BATCH_SIZE):
        batch = image_files[i:i + BATCH_SIZE]
        batch_num = (i // BATCH_SIZE) + 1
        
        logger.info(f"Processing batch {batch_num}/{total_batches} ({len(batch)} files)")
        
        success = upload_images_with_retry(batch, subdirectory)
        
        if success:
            successful_batches += 1
            logger.info(f"Batch {batch_num} completed successfully")
        else:
            logger.error(f"Batch {batch_num} failed")
            # Continue with remaining batches rather than stopping
        
        # Small delay between batches to be nice to the server
        if i + BATCH_SIZE < total_files:
            time.sleep(1)
    
    logger.info(f"Batch upload complete: {successful_batches}/{total_batches} batches successful")
    return successful_batches == total_batches


def check_image_api_health() -> bool:
    """Check if the image API is accessible"""
    try:
        response = requests.get(f"{API_BASE_URL}/api/image-upload-status", timeout=10)
        if response.status_code == 200:
            status = response.json()
            logger.info(f"Image API health check passed: {status.get('message', 'OK')}")
            total_images = status.get('total_images', 0)
            total_size_mb = status.get('total_size_mb', 0)
            logger.info(f"Current static directory contains {total_images} images ({total_size_mb:.1f}MB)")
            return True
        else:
            logger.error(f"Image API health check failed: {response.status_code}")
            return False
    except Exception as e:
        logger.error(f"Image API health check error: {e}")
        return False


def list_existing_images(subdirectory: str = "") -> List[str]:
    """List existing images on the server to avoid duplicates"""
    try:
        params = {"subdirectory": subdirectory} if subdirectory else {}
        response = requests.get(f"{API_BASE_URL}/api/images", params=params, timeout=10)
        
        if response.status_code == 200:
            result = response.json()
            existing_files = [img['filename'] for img in result.get('images', [])]
            logger.info(f"Found {len(existing_files)} existing images on server")
            return existing_files
        else:
            logger.warning(f"Could not list existing images: {response.status_code}")
            return []
    except Exception as e:
        logger.warning(f"Could not list existing images: {e}")
        return []


def filter_new_images(image_files: List[str], existing_images: List[str]) -> List[str]:
    """Filter out images that already exist on the server (comparing cleaned filenames)"""
    new_files = []
    for filepath in image_files:
        original_filename = os.path.basename(filepath)
        cleaned_filename = clean_filename(original_filename)
        
        if cleaned_filename not in existing_images:
            new_files.append(filepath)
        else:
            logger.info(f"Skipping {original_filename} -> {cleaned_filename} (already exists on server)")
    
    logger.info(f"Found {len(new_files)} new images to upload (skipped {len(image_files) - len(new_files)} existing)")
    return new_files


def main():
    """Main function to run the image upload process"""
    logger.info(f"Starting image upload process")
    logger.info(f"Images directory: {IMAGES_DIR}")
    logger.info(f"Target subdirectory: {SUBDIRECTORY or 'static (root)'}")

    # Check if images directory exists
    if not os.path.exists(IMAGES_DIR):
        logger.error(f"Images directory not found: {IMAGES_DIR}")
        sys.exit(1)

    # Find image files
    image_files = find_image_files(IMAGES_DIR)
    logger.info(f"Image files found: {[os.path.basename(f) for f in image_files[:10]]}{'...' if len(image_files) > 10 else ''}")
    
    if not image_files:
        logger.warning("No image files found to upload")
        return

    # Optional: Check for existing images to avoid duplicates
    existing_images = list_existing_images(SUBDIRECTORY)
    if existing_images:
        image_files = filter_new_images(image_files, existing_images)
        
        if not image_files:
            logger.info("All images already exist on server. Nothing to upload.")
            return

    # Upload files in batches
    if len(image_files) <= BATCH_SIZE:
        # Small number of files, upload all at once
        success = upload_images_with_retry(image_files, SUBDIRECTORY)
    else:
        # Large number of files, upload in batches
        success = upload_in_batches(image_files, SUBDIRECTORY)

    if success:
        logger.info("Image upload process completed successfully")
    else:
        logger.error("Image upload process failed")
        sys.exit(1)


if __name__ == "__main__":
    main()
# Out:
# 2025-07-04 23:30:32,523 INFO: Starting image upload process
# 2025-07-04 23:30:32,525 INFO: Images directory: /Users/adamshafikjovine/Documents/BOScheduling/metrics/plots
# 2025-07-04 23:30:32,526 INFO: Target subdirectory: plots
# 2025-07-04 23:30:32,539 INFO: Found 42 image files to upload
# 2025-07-04 23:30:32,539 INFO: Image files found: ['20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv.png', '20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv_dist.png', '20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv.png', '20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv_dist.png', '20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv.png', '20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv_dist.png', '20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv.png', '20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv_dist.png', '20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv.png', '20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv_dist.png']...
# 2025-07-04 23:30:38,416 INFO: Found 1292 existing images on server
# 2025-07-04 23:30:38,419 INFO: Found 42 new images to upload (skipped 0 existing)
# 2025-07-04 23:30:38,419 INFO: Uploading 42 files in 9 batches of 5
# 2025-07-04 23:30:38,420 INFO: Processing batch 1/9 (5 files)
# 2025-07-04 23:30:38,420 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:38,421 INFO: Filename cleaned: 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv.png -> 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.png
# 2025-07-04 23:30:38,421 INFO: Filename cleaned: 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv_dist.png -> 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9_dist.png
# 2025-07-04 23:30:38,422 INFO: Filename cleaned: 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv.png -> 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.png
# 2025-07-04 23:30:38,423 INFO: Filename cleaned: 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv_dist.png -> 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4_dist.png
# 2025-07-04 23:30:38,423 INFO: Filename cleaned: 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv.png -> 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.png
# 2025-07-04 23:30:38,424 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:38,424 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:38,475 INFO: Image upload successful: Processed 5 files, total size: 425,463 bytes
# 2025-07-04 23:30:38,475 INFO:   20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.png (was: 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv.png): SUCCESS - 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:38,476 INFO:     Web URL: /static/plots/20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.png
# 2025-07-04 23:30:38,476 INFO:   20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9_dist.png (was: 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9.csv_dist.png): SUCCESS - 20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:38,477 INFO:     Web URL: /static/plots/20250618_084824some_emptyi6-8d0078732dc682ba4635f756b052cbe9_dist.png
# 2025-07-04 23:30:38,477 INFO:   20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.png (was: 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv.png): SUCCESS - 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:38,478 INFO:     Web URL: /static/plots/20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.png
# 2025-07-04 23:30:38,478 INFO:   20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4_dist.png (was: 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4.csv_dist.png): SUCCESS - 20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:38,478 INFO:     Web URL: /static/plots/20250618_1126422324i127-7c9a292ed4f3032bd2c09b4b7d93eae4_dist.png
# 2025-07-04 23:30:38,479 INFO:   20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.png (was: 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv.png): SUCCESS - 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:38,479 INFO:     Web URL: /static/plots/20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.png
# 2025-07-04 23:30:38,479 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:38,480 INFO: Batch 1 completed successfully
# 2025-07-04 23:30:39,485 INFO: Processing batch 2/9 (5 files)
# 2025-07-04 23:30:39,485 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:39,486 INFO: Filename cleaned: 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv_dist.png -> 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34_dist.png
# 2025-07-04 23:30:39,486 INFO: Filename cleaned: 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv.png -> 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.png
# 2025-07-04 23:30:39,487 INFO: Filename cleaned: 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv_dist.png -> 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5_dist.png
# 2025-07-04 23:30:39,487 INFO: Filename cleaned: 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv.png -> 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.png
# 2025-07-04 23:30:39,487 INFO: Filename cleaned: 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv_dist.png -> 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78_dist.png
# 2025-07-04 23:30:39,488 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:39,488 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:39,541 INFO: Image upload successful: Processed 5 files, total size: 390,211 bytes
# 2025-07-04 23:30:39,542 INFO:   20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34_dist.png (was: 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34.csv_dist.png): SUCCESS - 20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:39,542 INFO:     Web URL: /static/plots/20250618_1126422324i135-db9101a8620a86349afb78dbd004fb34_dist.png
# 2025-07-04 23:30:39,542 INFO:   20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.png (was: 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv.png): SUCCESS - 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:39,543 INFO:     Web URL: /static/plots/20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.png
# 2025-07-04 23:30:39,543 INFO:   20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5_dist.png (was: 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5.csv_dist.png): SUCCESS - 20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:39,544 INFO:     Web URL: /static/plots/20250618_1126422324i151-dde79de178361831f7a1ac9de0d67af5_dist.png
# 2025-07-04 23:30:39,544 INFO:   20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.png (was: 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv.png): SUCCESS - 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:39,544 INFO:     Web URL: /static/plots/20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.png
# 2025-07-04 23:30:39,545 INFO:   20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78_dist.png (was: 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78.csv_dist.png): SUCCESS - 20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:39,545 INFO:     Web URL: /static/plots/20250618_1126422324i230-db9942e2e6dd7b9c2286c6abf1f84a78_dist.png
# 2025-07-04 23:30:39,545 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:39,546 INFO: Batch 2 completed successfully
# 2025-07-04 23:30:40,549 INFO: Processing batch 3/9 (5 files)
# 2025-07-04 23:30:40,555 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:40,556 INFO: Filename cleaned: 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.csv.png -> 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.png
# 2025-07-04 23:30:40,557 INFO: Filename cleaned: 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.csv_dist.png -> 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8_dist.png
# 2025-07-04 23:30:40,558 INFO: Filename cleaned: 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.csv.png -> 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.png
# 2025-07-04 23:30:40,559 INFO: Filename cleaned: 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.csv_dist.png -> 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd_dist.png
# 2025-07-04 23:30:40,559 INFO: Filename cleaned: 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.csv.png -> 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.png
# 2025-07-04 23:30:40,560 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:40,561 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:40,657 INFO: Image upload successful: Processed 5 files, total size: 428,266 bytes
# 2025-07-04 23:30:40,658 INFO:   20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.png (was: 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.csv.png): SUCCESS - 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:40,658 INFO:     Web URL: /static/plots/20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.png
# 2025-07-04 23:30:40,659 INFO:   20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8_dist.png (was: 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8.csv_dist.png): SUCCESS - 20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:40,659 INFO:     Web URL: /static/plots/20250618_1126422324i288-4626e3b0047d414e5bd245085d7defd8_dist.png
# 2025-07-04 23:30:40,660 INFO:   20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.png (was: 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.csv.png): SUCCESS - 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:40,661 INFO:     Web URL: /static/plots/20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.png
# 2025-07-04 23:30:40,661 INFO:   20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd_dist.png (was: 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd.csv_dist.png): SUCCESS - 20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:40,661 INFO:     Web URL: /static/plots/20250618_1126422324i295-dd765d5121140e4f590a32b8a39fb9bd_dist.png
# 2025-07-04 23:30:40,662 INFO:   20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.png (was: 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.csv.png): SUCCESS - 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:40,662 INFO:     Web URL: /static/plots/20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.png
# 2025-07-04 23:30:40,663 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:40,663 INFO: Batch 3 completed successfully
# 2025-07-04 23:30:41,668 INFO: Processing batch 4/9 (5 files)
# 2025-07-04 23:30:41,673 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:41,674 INFO: Filename cleaned: 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.csv_dist.png -> 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e_dist.png
# 2025-07-04 23:30:41,675 INFO: Filename cleaned: 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.csv.png -> 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.png
# 2025-07-04 23:30:41,675 INFO: Filename cleaned: 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.csv_dist.png -> 20250618_1126422324i73-c93041939746934550a4fba782fd7e05_dist.png
# 2025-07-04 23:30:41,675 INFO: Filename cleaned: 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.csv.png -> 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.png
# 2025-07-04 23:30:41,676 INFO: Filename cleaned: 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.csv_dist.png -> 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37_dist.png
# 2025-07-04 23:30:41,676 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:41,676 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:41,850 INFO: Image upload successful: Processed 5 files, total size: 389,684 bytes
# 2025-07-04 23:30:41,850 INFO:   20250618_1126422324i319-9aa335c246e2914035d720b013977c2e_dist.png (was: 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e.csv_dist.png): SUCCESS - 20250618_1126422324i319-9aa335c246e2914035d720b013977c2e_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:41,851 INFO:     Web URL: /static/plots/20250618_1126422324i319-9aa335c246e2914035d720b013977c2e_dist.png
# 2025-07-04 23:30:41,851 INFO:   20250618_1126422324i73-c93041939746934550a4fba782fd7e05.png (was: 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.csv.png): SUCCESS - 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:41,852 INFO:     Web URL: /static/plots/20250618_1126422324i73-c93041939746934550a4fba782fd7e05.png
# 2025-07-04 23:30:41,853 INFO:   20250618_1126422324i73-c93041939746934550a4fba782fd7e05_dist.png (was: 20250618_1126422324i73-c93041939746934550a4fba782fd7e05.csv_dist.png): SUCCESS - 20250618_1126422324i73-c93041939746934550a4fba782fd7e05_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:41,855 INFO:     Web URL: /static/plots/20250618_1126422324i73-c93041939746934550a4fba782fd7e05_dist.png
# 2025-07-04 23:30:41,855 INFO:   20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.png (was: 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.csv.png): SUCCESS - 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:41,856 INFO:     Web URL: /static/plots/20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.png
# 2025-07-04 23:30:41,856 INFO:   20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37_dist.png (was: 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37.csv_dist.png): SUCCESS - 20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:41,857 INFO:     Web URL: /static/plots/20250618_162231242124i122-e853afd1e10a887b7f1c158d01e10c37_dist.png
# 2025-07-04 23:30:41,857 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:41,857 INFO: Batch 4 completed successfully
# 2025-07-04 23:30:42,861 INFO: Processing batch 5/9 (5 files)
# 2025-07-04 23:30:42,864 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:42,865 INFO: Filename cleaned: 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.csv.png -> 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.png
# 2025-07-04 23:30:42,866 INFO: Filename cleaned: 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.csv_dist.png -> 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8_dist.png
# 2025-07-04 23:30:42,866 INFO: Filename cleaned: 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.csv.png -> 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.png
# 2025-07-04 23:30:42,867 INFO: Filename cleaned: 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.csv_dist.png -> 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94_dist.png
# 2025-07-04 23:30:42,867 INFO: Filename cleaned: 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.csv.png -> 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.png
# 2025-07-04 23:30:42,867 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:42,868 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:42,977 INFO: Image upload successful: Processed 5 files, total size: 430,682 bytes
# 2025-07-04 23:30:42,978 INFO:   20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.png (was: 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.csv.png): SUCCESS - 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:42,978 INFO:     Web URL: /static/plots/20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.png
# 2025-07-04 23:30:42,978 INFO:   20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8_dist.png (was: 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8.csv_dist.png): SUCCESS - 20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:42,978 INFO:     Web URL: /static/plots/20250618_162231242124i143-4affc173ff203dba771065bc874b2ae8_dist.png
# 2025-07-04 23:30:42,978 INFO:   20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.png (was: 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.csv.png): SUCCESS - 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:42,979 INFO:     Web URL: /static/plots/20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.png
# 2025-07-04 23:30:42,979 INFO:   20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94_dist.png (was: 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94.csv_dist.png): SUCCESS - 20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:42,980 INFO:     Web URL: /static/plots/20250618_162231242124i145-425ce3a587a95d6620db372bb555cc94_dist.png
# 2025-07-04 23:30:42,980 INFO:   20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.png (was: 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.csv.png): SUCCESS - 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:42,980 INFO:     Web URL: /static/plots/20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.png
# 2025-07-04 23:30:42,981 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:42,981 INFO: Batch 5 completed successfully
# 2025-07-04 23:30:43,987 INFO: Processing batch 6/9 (5 files)
# 2025-07-04 23:30:43,988 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:43,989 INFO: Filename cleaned: 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.csv_dist.png -> 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe_dist.png
# 2025-07-04 23:30:43,989 INFO: Filename cleaned: 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.csv.png -> 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.png
# 2025-07-04 23:30:43,990 INFO: Filename cleaned: 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.csv_dist.png -> 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7_dist.png
# 2025-07-04 23:30:43,990 INFO: Filename cleaned: 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.csv.png -> 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.png
# 2025-07-04 23:30:43,991 INFO: Filename cleaned: 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.csv_dist.png -> 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c_dist.png
# 2025-07-04 23:30:43,991 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:43,992 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:44,055 INFO: Image upload successful: Processed 5 files, total size: 390,724 bytes
# 2025-07-04 23:30:44,056 INFO:   20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe_dist.png (was: 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe.csv_dist.png): SUCCESS - 20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:44,057 INFO:     Web URL: /static/plots/20250618_162231242124i149-15de6e168911444f553a06eb6e2957fe_dist.png
# 2025-07-04 23:30:44,058 INFO:   20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.png (was: 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.csv.png): SUCCESS - 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:44,058 INFO:     Web URL: /static/plots/20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.png
# 2025-07-04 23:30:44,059 INFO:   20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7_dist.png (was: 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7.csv_dist.png): SUCCESS - 20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:44,060 INFO:     Web URL: /static/plots/20250618_162231242124i175-6cd900d8e961a7d77b38dc6a998ce0e7_dist.png
# 2025-07-04 23:30:44,060 INFO:   20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.png (was: 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.csv.png): SUCCESS - 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:44,061 INFO:     Web URL: /static/plots/20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.png
# 2025-07-04 23:30:44,062 INFO:   20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c_dist.png (was: 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c.csv_dist.png): SUCCESS - 20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:44,063 INFO:     Web URL: /static/plots/20250618_162231242124i310-32cb92fd54b1fe6ee73646a7812d090c_dist.png
# 2025-07-04 23:30:44,063 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:44,064 INFO: Batch 6 completed successfully
# 2025-07-04 23:30:45,067 INFO: Processing batch 7/9 (5 files)
# 2025-07-04 23:30:45,068 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:45,068 INFO: Filename cleaned: 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.csv.png -> 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.png
# 2025-07-04 23:30:45,069 INFO: Filename cleaned: 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.csv_dist.png -> 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47_dist.png
# 2025-07-04 23:30:45,069 INFO: Filename cleaned: 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.csv.png -> 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.png
# 2025-07-04 23:30:45,069 INFO: Filename cleaned: 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.csv_dist.png -> 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf_dist.png
# 2025-07-04 23:30:45,070 INFO: Filename cleaned: 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.csv.png -> 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.png
# 2025-07-04 23:30:45,070 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:45,070 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:45,109 INFO: Image upload successful: Processed 5 files, total size: 431,129 bytes
# 2025-07-04 23:30:45,109 INFO:   20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.png (was: 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.csv.png): SUCCESS - 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:45,110 INFO:     Web URL: /static/plots/20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.png
# 2025-07-04 23:30:45,110 INFO:   20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47_dist.png (was: 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47.csv_dist.png): SUCCESS - 20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:45,110 INFO:     Web URL: /static/plots/20250618_162231242124i37-7ec2808e4f773577c243dcd658c45a47_dist.png
# 2025-07-04 23:30:45,111 INFO:   20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.png (was: 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.csv.png): SUCCESS - 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:45,111 INFO:     Web URL: /static/plots/20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.png
# 2025-07-04 23:30:45,112 INFO:   20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf_dist.png (was: 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf.csv_dist.png): SUCCESS - 20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:45,113 INFO:     Web URL: /static/plots/20250618_162231242124i389-e3d1e23188b418dec7b4536481c60edf_dist.png
# 2025-07-04 23:30:45,113 INFO:   20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.png (was: 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.csv.png): SUCCESS - 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:45,116 INFO:     Web URL: /static/plots/20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.png
# 2025-07-04 23:30:45,118 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:45,119 INFO: Batch 7 completed successfully
# 2025-07-04 23:30:46,120 INFO: Processing batch 8/9 (5 files)
# 2025-07-04 23:30:46,122 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:46,123 INFO: Filename cleaned: 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.csv_dist.png -> 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6_dist.png
# 2025-07-04 23:30:46,124 INFO: Filename cleaned: 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.csv.png -> 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.png
# 2025-07-04 23:30:46,125 INFO: Filename cleaned: 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.csv_dist.png -> 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d_dist.png
# 2025-07-04 23:30:46,126 INFO: Filename cleaned: 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.csv.png -> 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.png
# 2025-07-04 23:30:46,126 INFO: Filename cleaned: 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.csv_dist.png -> 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc_dist.png
# 2025-07-04 23:30:46,127 INFO: Uploading 5 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:46,127 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:46,206 INFO: Image upload successful: Processed 5 files, total size: 389,535 bytes
# 2025-07-04 23:30:46,207 INFO:   20250618_162231242124i395-8ae3083212016466420d651ece92a4a6_dist.png (was: 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6.csv_dist.png): SUCCESS - 20250618_162231242124i395-8ae3083212016466420d651ece92a4a6_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:46,208 INFO:     Web URL: /static/plots/20250618_162231242124i395-8ae3083212016466420d651ece92a4a6_dist.png
# 2025-07-04 23:30:46,208 INFO:   20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.png (was: 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.csv.png): SUCCESS - 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:46,208 INFO:     Web URL: /static/plots/20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.png
# 2025-07-04 23:30:46,209 INFO:   20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d_dist.png (was: 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d.csv_dist.png): SUCCESS - 20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:46,209 INFO:     Web URL: /static/plots/20250618_162231242124i40-a284c8974f3a842ab9c095b05055643d_dist.png
# 2025-07-04 23:30:46,209 INFO:   20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.png (was: 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.csv.png): SUCCESS - 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:46,209 INFO:     Web URL: /static/plots/20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.png
# 2025-07-04 23:30:46,210 INFO:   20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc_dist.png (was: 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc.csv_dist.png): SUCCESS - 20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:46,210 INFO:     Web URL: /static/plots/20250618_162231242124i47-bba5ab5e82a2d2de3d065d9d388087dc_dist.png
# 2025-07-04 23:30:46,210 INFO: Successfully processed 5 files, 0.4MB total
# 2025-07-04 23:30:46,211 INFO: Batch 8 completed successfully
# 2025-07-04 23:30:47,216 INFO: Processing batch 9/9 (2 files)
# 2025-07-04 23:30:47,219 INFO: Image upload attempt 1/3
# 2025-07-04 23:30:47,224 INFO: Filename cleaned: 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.csv.png -> 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.png
# 2025-07-04 23:30:47,226 INFO: Filename cleaned: 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.csv_dist.png -> 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11_dist.png
# 2025-07-04 23:30:47,227 INFO: Uploading 2 image files to http://localhost:8000/api/upload-images
# 2025-07-04 23:30:47,227 INFO: Target subdirectory: static/plots/
# 2025-07-04 23:30:47,257 INFO: Image upload successful: Processed 2 files, total size: 164,599 bytes
# 2025-07-04 23:30:47,259 INFO:   20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.png (was: 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.csv.png): SUCCESS - 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:47,259 INFO:     Web URL: /static/plots/20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.png
# 2025-07-04 23:30:47,259 INFO:   20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11_dist.png (was: 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11.csv_dist.png): SUCCESS - 20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11_dist.png (1800x1200, 0.1MB)
# 2025-07-04 23:30:47,260 INFO:     Web URL: /static/plots/20250618_162231242124i50-8ee6a442da7267696b2e1c89582a1e11_dist.png
# 2025-07-04 23:30:47,260 INFO: Successfully processed 2 files, 0.2MB total
# 2025-07-04 23:30:47,265 INFO: Batch 9 completed successfully
# 2025-07-04 23:30:47,265 INFO: Batch upload complete: 9/9 batches successful
# 2025-07-04 23:30:47,266 INFO: Image upload process completed successfully

# %%
#!/usr/bin/env python3
"""
Script to check files in the backend/app/static/plots directory
"""

import os
import glob
from pathlib import Path
from datetime import datetime
from typing import List, Dict

def check_static_plots_directory():
    """Check files in the backend/app/static/plots directory"""
    
    # Define the path
    plots_dir = "../backend/app/static/plots"
    absolute_path = os.path.abspath(plots_dir)
    
    print("=" * 60)
    print("CHECKING BACKEND STATIC PLOTS DIRECTORY")
    print("=" * 60)
    print(f"Directory path: {plots_dir}")
    print(f"Absolute path: {absolute_path}")
    print()
    
    # Check if directory exists
    if not os.path.exists(plots_dir):
        print("❌ Directory does not exist!")
        return
    
    if not os.path.isdir(plots_dir):
        print("❌ Path exists but is not a directory!")
        return
    
    print("✅ Directory exists")
    
    # Check permissions
    readable = os.access(plots_dir, os.R_OK)
    writable = os.access(plots_dir, os.W_OK)
    executable = os.access(plots_dir, os.X_OK)
    
    print(f"📁 Directory permissions:")
    print(f"   Read: {'✅' if readable else '❌'}")
    print(f"   Write: {'✅' if writable else '❌'}")
    print(f"   Execute: {'✅' if executable else '❌'}")
    print()
    
    # List all files
    try:
        all_files = os.listdir(plots_dir)
        all_files.sort()
        
        print(f"📊 Total items in directory: {len(all_files)}")
        print()
        
        # Filter for image files
        image_extensions = {'.png', '.jpg', '.jpeg', '.gif', '.bmp', '.webp', '.tiff'}
        image_files = []
        other_files = []
        
        for file in all_files:
            file_path = os.path.join(plots_dir, file)
            if os.path.isfile(file_path):
                ext = os.path.splitext(file)[1].lower()
                if ext in image_extensions:
                    image_files.append(file)
                else:
                    other_files.append(file)
        
        print(f"🖼️  Image files found: {len(image_files)}")
        print(f"📄 Other files found: {len(other_files)}")
        print()
        
        # Show image files with details
        if image_files:
            print("IMAGE FILES:")
            print("-" * 50)
            total_size = 0
            
            for filename in image_files:
                file_path = os.path.join(plots_dir, filename)
                try:
                    stat = os.stat(file_path)
                    size_mb = stat.st_size / (1024 * 1024)
                    modified = datetime.fromtimestamp(stat.st_mtime)
                    total_size += stat.st_size
                    
                    print(f"📸 {filename}")
                    print(f"   Size: {size_mb:.2f} MB")
                    print(f"   Modified: {modified.strftime('%Y-%m-%d %H:%M:%S')}")
                    print()
                    
                except Exception as e:
                    print(f"❌ Error reading {filename}: {e}")
            
            total_size_mb = total_size / (1024 * 1024)
            print(f"💾 Total image size: {total_size_mb:.2f} MB")
            print()
        
        # Show other files
        if other_files:
            print("OTHER FILES:")
            print("-" * 50)
            for filename in other_files:
                file_path = os.path.join(plots_dir, filename)
                try:
                    stat = os.stat(file_path)
                    size_kb = stat.st_size / 1024
                    print(f"📄 {filename} ({size_kb:.1f} KB)")
                except Exception as e:
                    print(f"❌ Error reading {filename}: {e}")
            print()
        
        # Check for specific date patterns (like your 20250614 files)
        date_pattern_files = []
        for file in image_files:
            if file.startswith("20250614"):
                date_pattern_files.append(file)
        
        if date_pattern_files:
            print(f"📅 Files matching '20250614*' pattern: {len(date_pattern_files)}")
            for file in date_pattern_files[:10]:  # Show first 10
                print(f"   - {file}")
            if len(date_pattern_files) > 10:
                print(f"   ... and {len(date_pattern_files) - 10} more")
            print()
        
        # Directory structure
        print("DIRECTORY STRUCTURE:")
        print("-" * 50)
        for root, dirs, files in os.walk(plots_dir):
            level = root.replace(plots_dir, '').count(os.sep)
            indent = ' ' * 2 * level
            print(f"{indent}{os.path.basename(root)}/")
            subindent = ' ' * 2 * (level + 1)
            for file in files[:5]:  # Show first 5 files per directory
                print(f"{subindent}{file}")
            if len(files) > 5:
                print(f"{subindent}... and {len(files) - 5} more files")
    
    except PermissionError:
        print("❌ Permission denied reading directory")
    except Exception as e:
        print(f"❌ Error reading directory: {e}")


def check_docker_mount_compatibility():
    """Check if the directory structure is compatible with Docker mounting"""
    
    print("=" * 60)
    print("DOCKER MOUNT COMPATIBILITY CHECK")
    print("=" * 60)
    
    # Check if backend directory exists
    backend_dir = "../backend"
    if not os.path.exists(backend_dir):
        print("❌ ./backend directory not found!")
        print("   Make sure you're running this from the project root")
        return
    
    # Check the full path structure
    paths_to_check = [
        "../backend",
        "../backend/app", 
        "../backend/app/static",
        "../backend/app/static/plots"
    ]
    
    for path in paths_to_check:
        if os.path.exists(path):
            print(f"✅ {path}")
        else:
            print(f"❌ {path} - Missing!")
    
    print()
    
    # Check if we're in the right directory
    current_files = os.listdir(".")
    expected_files = ["backend", "docker-compose.yml", "Dockerfile"]
    
    print("Current directory contains:")
    for file in current_files:
        marker = "✅" if file in expected_files else "📄"
        print(f"   {marker} {file}")
    
    missing_expected = [f for f in expected_files if f not in current_files]
    if missing_expected:
        print(f"\n⚠️  Missing expected files: {missing_expected}")
        print("   You might not be in the project root directory")


if __name__ == "__main__":
    check_static_plots_directory()
    print()
    check_docker_mount_compatibility()
# Out:
# ============================================================
# CHECKING BACKEND STATIC PLOTS DIRECTORY
# ============================================================
# Directory path: ../backend/app/static/plots
# Absolute path: /Users/adamshafikjovine/Documents/BOScheduling/backend/app/static/plots
#
# ✅ Directory exists
# 📁 Directory permissions:
#    Read: ✅
#    Write: ✅
#    Execute: ✅
#
# 📊 Total items in directory: 1292
#
# 🖼️  Image files found: 1292
# 📄 Other files found: 0
#
# IMAGE FILES:
# --------------------------------------------------
# 📸 20250624_041000i10random-acb3bf9268fe61f634aa05e162258c4c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i10random-acb3bf9268fe61f634aa05e162258c4c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i11random-86d59c8115a1802420114e88ce8b3064.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i11random-86d59c8115a1802420114e88ce8b3064_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i12random-0e8bf1c032aa730093a40668fd3a51e7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i12random-0e8bf1c032aa730093a40668fd3a51e7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i13random-ded6ba78dee62524cf555d253c0f9cd8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i13random-ded6ba78dee62524cf555d253c0f9cd8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i14random-eb21eb1451ee002fafa2ada315b0757e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i14random-eb21eb1451ee002fafa2ada315b0757e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i15random-e146170f16b653f44773b639b5560415.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i15random-e146170f16b653f44773b639b5560415_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i16random-d4740674d990686c0140841c446327cc.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i16random-d4740674d990686c0140841c446327cc_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i17random-0ddfa795273776f63302532c7dfe508e.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i17random-0ddfa795273776f63302532c7dfe508e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i18random-d55829aba8ca43a5e68fa2402dd5a182.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i18random-d55829aba8ca43a5e68fa2402dd5a182_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i19random-034287ccf6995f4c36aa52f802cb6a96.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i19random-034287ccf6995f4c36aa52f802cb6a96_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i1random-893703699355a2e8bedd297201c4dc2f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i1random-893703699355a2e8bedd297201c4dc2f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i20random-67a33f02621faa248bd19b89e0a40cd2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i20random-67a33f02621faa248bd19b89e0a40cd2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i21random-1df0073151b78364e42f991a0d866ee8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i21random-1df0073151b78364e42f991a0d866ee8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i22random-8c288ea901344321787089dbdbbc3194.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i22random-8c288ea901344321787089dbdbbc3194_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i23random-f31c7ced8366953ccbd5e6e904e05d18.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i23random-f31c7ced8366953ccbd5e6e904e05d18_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i24random-4b391568dd80637f71f10547e47593cd.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i24random-4b391568dd80637f71f10547e47593cd_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i25random-ca175cc3b6a8efb8bf0512c6cb9036ed.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i25random-ca175cc3b6a8efb8bf0512c6cb9036ed_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i26random-3072cacd93f8543dc9d167617b453ce9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i26random-3072cacd93f8543dc9d167617b453ce9_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i27random-5d8fe37071e6944d6db38e6575e2b94f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i27random-5d8fe37071e6944d6db38e6575e2b94f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i28random-541d1f1a5aaaa81fea58e419ab863187.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i28random-541d1f1a5aaaa81fea58e419ab863187_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i29random-d328cdc00f9a160280f4c361c423b20d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i29random-d328cdc00f9a160280f4c361c423b20d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i2random-79f6c1a540330e10755e682439c37b28.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i2random-79f6c1a540330e10755e682439c37b28_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i30random-4617a09dcf22debb7f6d1637904fef00.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i30random-4617a09dcf22debb7f6d1637904fef00_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i31random-e0e81db888fc717dfcfc1dfcc13cd816.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i31random-e0e81db888fc717dfcfc1dfcc13cd816_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i32random-c7d1e8c693268ad0c2e3ed53039420e8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i32random-c7d1e8c693268ad0c2e3ed53039420e8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i33random-9035d34e90377c88e748790af53b40db.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i33random-9035d34e90377c88e748790af53b40db_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i34random-7c3c38b6efb1c6c8a6761dffbccbdd7c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i34random-7c3c38b6efb1c6c8a6761dffbccbdd7c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i35random-d5b617a0701402f398da8d68120544b2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i35random-d5b617a0701402f398da8d68120544b2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i36random-3d0c50f3cc4b5c45f595df4713d62e7c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i36random-3d0c50f3cc4b5c45f595df4713d62e7c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i37random-fa70bf7a29b0916f3d14a7385b927042.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i37random-fa70bf7a29b0916f3d14a7385b927042_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i38random-0c1a2689a43aa72035bc403e667a7abf.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i38random-0c1a2689a43aa72035bc403e667a7abf_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i39random-adc3635ed481f4bd97c54a15d2dfc977.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i39random-adc3635ed481f4bd97c54a15d2dfc977_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i3random-e6f62b010123f72749c2095759442409.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i3random-e6f62b010123f72749c2095759442409_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i40random-133a511a77b401e3caaeb8ee799019a7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i40random-133a511a77b401e3caaeb8ee799019a7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i41random-e4eabcf953c44cfc92511f1ed1d1b1fb.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i41random-e4eabcf953c44cfc92511f1ed1d1b1fb_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i42random-61f8cc5376bbac556d596180f4d1efbf.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i42random-61f8cc5376bbac556d596180f4d1efbf_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i43random-88e81647913ee783bb838bb02c9a86ca.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i43random-88e81647913ee783bb838bb02c9a86ca_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i44random-f05084776d3de97f276329624b936519.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i44random-f05084776d3de97f276329624b936519_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i45random-38a3fb747ad2e8d93a8d53e76232d733.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i45random-38a3fb747ad2e8d93a8d53e76232d733_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i46random-8923ed68764a58bdf6ba2a663f82a62e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i46random-8923ed68764a58bdf6ba2a663f82a62e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i47random-e633143a047c7165d3ab0e34c9861eb0.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i47random-e633143a047c7165d3ab0e34c9861eb0_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i48random-7c5c6dfba77e3e8256b12622d37a61f0.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i48random-7c5c6dfba77e3e8256b12622d37a61f0_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i49random-b47da3a64e86883d6410c90de4e13210.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i49random-b47da3a64e86883d6410c90de4e13210_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i4random-9451bea01e2be81fe1ca6f1ff2b62026.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i4random-9451bea01e2be81fe1ca6f1ff2b62026_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i50random-2c23b1e48d96057cdd900985d32a6b97.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i50random-2c23b1e48d96057cdd900985d32a6b97_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i51random-0225b6f0dacefc4a36ea4e7592e56ad4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i51random-0225b6f0dacefc4a36ea4e7592e56ad4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i52random-3c1eb516de47dc6856daeb60abf9bcf7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i52random-3c1eb516de47dc6856daeb60abf9bcf7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i53random-363108b05e66a4de6f5247dc25362277.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i53random-363108b05e66a4de6f5247dc25362277_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i54random-39101adbac6a36c9f062df84a8b1647a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i54random-39101adbac6a36c9f062df84a8b1647a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i55random-f2d49fd037e16bfbf4a360ee0c9501e4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i55random-f2d49fd037e16bfbf4a360ee0c9501e4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i56random-763ccf2c30c48e428fb2e90c86591c69.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i56random-763ccf2c30c48e428fb2e90c86591c69_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i57random-863c2cd75fac70b4b2cd0f75a09013c2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i57random-863c2cd75fac70b4b2cd0f75a09013c2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i5random-7400a51581e239f8491be35b96d203f3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i5random-7400a51581e239f8491be35b96d203f3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i6random-7a1aa4af14e3f09e5f7c10c275f156cf.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i6random-7a1aa4af14e3f09e5f7c10c275f156cf_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i7random-1ed758efe7a14db4bb7281aa9b8b1024.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i7random-1ed758efe7a14db4bb7281aa9b8b1024_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i8random-85a04b2a2a3ba5ec1ec5463be3113188.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i8random-85a04b2a2a3ba5ec1ec5463be3113188_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i9random-119d2dc95b97d83c2850455f83c8850a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041000i9random-119d2dc95b97d83c2850455f83c8850a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i1parego-1a18de54628d141e81ead8c1dfa83ec8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i1parego-1a18de54628d141e81ead8c1dfa83ec8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i2parego-86384165d8ea479464f57b0402e3171d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i2parego-86384165d8ea479464f57b0402e3171d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i3parego-793309ee67a8d20d1cbd5edcb165d341.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i3parego-793309ee67a8d20d1cbd5edcb165d341_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i4parego-6606f63564cabde76a7c1c8aa4800ee9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i4parego-6606f63564cabde76a7c1c8aa4800ee9_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i5parego-2bf12465fcc0faf89c6b5bb693f51dec.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i5parego-2bf12465fcc0faf89c6b5bb693f51dec_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i6parego-98e914b3526a52fbf3c30cc5952e3db8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_041023i6parego-98e914b3526a52fbf3c30cc5952e3db8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i1parego-945926440708ead3381692fe104056cd.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i1parego-945926440708ead3381692fe104056cd_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i2parego-b819588c880d4fb87b293ce450940dc5.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i2parego-b819588c880d4fb87b293ce450940dc5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i3parego-0ce36646a4e15b67fc5f7bd50d4ffc53.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i3parego-0ce36646a4e15b67fc5f7bd50d4ffc53_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i4parego-7e5c6a10e85245f96354f552fc01258d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i4parego-7e5c6a10e85245f96354f552fc01258d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i5parego-481a246a1be1bb4d89e59b57a38380e5.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i5parego-481a246a1be1bb4d89e59b57a38380e5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i6parego-e8cc99dd5d3c618f289ffb23c8f3b497.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_042011i6parego-e8cc99dd5d3c618f289ffb23c8f3b497_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i10thompson-3ec4820f0c1b823b7bb009fdf3b66f22.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i10thompson-3ec4820f0c1b823b7bb009fdf3b66f22_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i11thompson-b1a9db4be8aed9d6193d496305770bd5.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i11thompson-b1a9db4be8aed9d6193d496305770bd5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i12thompson-9bc989534ea42db29d2061cbd29080f0.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i12thompson-9bc989534ea42db29d2061cbd29080f0_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i13thompson-5f285fe5984347c99780818fd3726512.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i13thompson-5f285fe5984347c99780818fd3726512_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i14thompson-fc272c459a5f8e493b44f8560ae1aad6.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i14thompson-fc272c459a5f8e493b44f8560ae1aad6_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i15thompson-43ec5434230a9fd4fa4c17dfdf555f67.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i15thompson-43ec5434230a9fd4fa4c17dfdf555f67_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i16thompson-df619d2bd162dedfa7a41ec8101c5dbb.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i16thompson-df619d2bd162dedfa7a41ec8101c5dbb_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i17thompson-5e5669886e9601ce443db95ed89d133d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i17thompson-5e5669886e9601ce443db95ed89d133d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i18thompson-8b2116dcb9c23863f3b2e4591a29923f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i18thompson-8b2116dcb9c23863f3b2e4591a29923f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i19thompson-605a1032b38a11814913632ee0594869.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i19thompson-605a1032b38a11814913632ee0594869_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i1thompson-b614c8af0ea1b255dac71ae2ec08d4e4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i1thompson-b614c8af0ea1b255dac71ae2ec08d4e4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i20thompson-0fd157ad1319983cc1d3f563393c9c12.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i20thompson-0fd157ad1319983cc1d3f563393c9c12_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i21thompson-5b29564438a1c5809a23e42035e8f9ca.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i21thompson-5b29564438a1c5809a23e42035e8f9ca_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i22thompson-b34ad60cce5ada7ec6c4df97b2177ca5.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i22thompson-b34ad60cce5ada7ec6c4df97b2177ca5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i23thompson-4083b00777f8a9f7aa9b704768e272dd.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i23thompson-4083b00777f8a9f7aa9b704768e272dd_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i24thompson-797afc9bc0d794f1d1f8f574cc8e10ee.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i24thompson-797afc9bc0d794f1d1f8f574cc8e10ee_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i25thompson-548d36fd7e6dc5a395d206a7bfa6b109.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i25thompson-548d36fd7e6dc5a395d206a7bfa6b109_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i26thompson-a6aed641c815527e35e38c9b8b125b2b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i26thompson-a6aed641c815527e35e38c9b8b125b2b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i27thompson-e7e7bc090b6f476a6a90c3e513069a2f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i27thompson-e7e7bc090b6f476a6a90c3e513069a2f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i28thompson-e22e8df717b0e69549291ad66070afb4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i28thompson-e22e8df717b0e69549291ad66070afb4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i29thompson-3f08998aa9e71f2f358808404a8298e8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i29thompson-3f08998aa9e71f2f358808404a8298e8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i2thompson-05d467df32d436360f823e3d788b0583.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i2thompson-05d467df32d436360f823e3d788b0583_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i30thompson-409b38fe3030c58313e583e6062e39f7.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i30thompson-409b38fe3030c58313e583e6062e39f7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i31thompson-75e752d6076e20c0ed41049b5aa8cc8e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i31thompson-75e752d6076e20c0ed41049b5aa8cc8e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i32thompson-55a0d86c17244a54c4c83f9fdddc56a4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i32thompson-55a0d86c17244a54c4c83f9fdddc56a4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i33thompson-3ce97d2769fe6fce803fe3f84f6a2273.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i33thompson-3ce97d2769fe6fce803fe3f84f6a2273_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i34thompson-8095b36ac85f6e3ef2a1cc8934a610a5.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i34thompson-8095b36ac85f6e3ef2a1cc8934a610a5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i35thompson-1832928b3d5f48ece1f478a95cc94e9c.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i35thompson-1832928b3d5f48ece1f478a95cc94e9c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i36thompson-27bf18c94164581975e896ccea285700.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i36thompson-27bf18c94164581975e896ccea285700_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i37thompson-4ea4757ecae93dcd7ecc8844e403f0d9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i37thompson-4ea4757ecae93dcd7ecc8844e403f0d9_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i38thompson-458f5bf39ce916d7cc17600649b65ee3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i38thompson-458f5bf39ce916d7cc17600649b65ee3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i39thompson-faf8af411eace25529e614605cc669dc.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i39thompson-faf8af411eace25529e614605cc669dc_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i3thompson-813f33339740e2d9c5bfee72d8664b4b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i3thompson-813f33339740e2d9c5bfee72d8664b4b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i40thompson-19e8d728f06e0f6cbc5b05c9c881c088.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i40thompson-19e8d728f06e0f6cbc5b05c9c881c088_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i4thompson-30f58d85e02b5e509aa992f5ef437e35.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i4thompson-30f58d85e02b5e509aa992f5ef437e35_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i5thompson-f027a4df3c2a32caf546249f64432842.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i5thompson-f027a4df3c2a32caf546249f64432842_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i6thompson-227242bbd5b80fc5463901225fc150e8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i6thompson-227242bbd5b80fc5463901225fc150e8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i7thompson-2d36ffa8f426b8e13a790d60f4e2c058.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i7thompson-2d36ffa8f426b8e13a790d60f4e2c058_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i8thompson-6e7bd221bdb97fe5b253424b56e10fea.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i8thompson-6e7bd221bdb97fe5b253424b56e10fea_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i9thompson-5acdcdf9b7a3af2d4c7a2dc3766c4cb3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_045838i9thompson-5acdcdf9b7a3af2d4c7a2dc3766c4cb3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i1parego-d67a7a172b61070779378bc10bc0865a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i1parego-d67a7a172b61070779378bc10bc0865a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i2parego-09b850bb9ad34b9512ded6387a0870e6.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i2parego-09b850bb9ad34b9512ded6387a0870e6_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i3parego-ca0447732d82131f1bf4248b952bd193.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i3parego-ca0447732d82131f1bf4248b952bd193_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i4parego-9adb37bfe32c316963f287e2b6f53874.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i4parego-9adb37bfe32c316963f287e2b6f53874_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i5parego-2c6c4b83b7e7c5d70f9db874f78e682f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i5parego-2c6c4b83b7e7c5d70f9db874f78e682f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i6parego-49445771466dd95a67084f8e4b76e3a6.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_050554i6parego-49445771466dd95a67084f8e4b76e3a6_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i11parego-42d8935d91a18a28c8e0426818029d5b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i11parego-42d8935d91a18a28c8e0426818029d5b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i1parego-0a7e414bebc19caa910519a6cf01367b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i1parego-0a7e414bebc19caa910519a6cf01367b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i2parego-7d0db6bfb531f7479281929a1700b990.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i2parego-7d0db6bfb531f7479281929a1700b990_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i3parego-9e40ede773ed91ee397e8fb5edd15353.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i3parego-9e40ede773ed91ee397e8fb5edd15353_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i4parego-33eec6bba22f613462bd2d2d7e980109.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i4parego-33eec6bba22f613462bd2d2d7e980109_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i5parego-092a409d5c1eaebb5f28796cb7e455ea.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i5parego-092a409d5c1eaebb5f28796cb7e455ea_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i6parego-dfaf761c2fc3771828f2bd66f7cefc12.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i6parego-dfaf761c2fc3771828f2bd66f7cefc12_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i7parego-abbf3f0b9152b01ee082714b4e695281.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i7parego-abbf3f0b9152b01ee082714b4e695281_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i8parego-de639e2aac3a34a7c2214c19c89b502b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i8parego-de639e2aac3a34a7c2214c19c89b502b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i9parego-ab2ae2343e0c324cf7eddddfd0f059ca.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_054053i9parego-ab2ae2343e0c324cf7eddddfd0f059ca_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i1parego_1.2-a664db64fdd3e962b634ff5972203076.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i1parego_1.2-a664db64fdd3e962b634ff5972203076_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i2parego_1.2-4cceb00160a418ba7d343cfbd3115e85.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i2parego_1.2-4cceb00160a418ba7d343cfbd3115e85_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i3parego_1.2-aed55b996314a846837be3e6351e9552.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i3parego_1.2-aed55b996314a846837be3e6351e9552_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i4parego_1.2-2c0faaebd5d40d01266e409d7e4a9dec.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i4parego_1.2-2c0faaebd5d40d01266e409d7e4a9dec_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_063311i5parego_1.2-5bf84ea7633e99237780aa71bc191d24.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i100par___-675d644d4c10b41f2e86b75b07dc7e50.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i100par___-675d644d4c10b41f2e86b75b07dc7e50_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i101par___-5aa9ed4eb3d7bd0b3b8abb0f77979b5b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i101par___-5aa9ed4eb3d7bd0b3b8abb0f77979b5b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i102par___-3a46b5ce44b5a36c5be17cd6d98f264c.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i102par___-3a46b5ce44b5a36c5be17cd6d98f264c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i103par___-c52322e759ccfefcb6443338ca84f10f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i103par___-c52322e759ccfefcb6443338ca84f10f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i104par___-361b485e49d1fd99370fe5d435883e6f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i104par___-361b485e49d1fd99370fe5d435883e6f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i105par___-89377958cd01cf70ecddbf1e4b4b6215.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i105par___-89377958cd01cf70ecddbf1e4b4b6215_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i106par___-f2321cf8f41e825569271a37462a73a2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i106par___-f2321cf8f41e825569271a37462a73a2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i107par___-3ffa10fa495cbb928abef6f4dbcf92ba.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i107par___-3ffa10fa495cbb928abef6f4dbcf92ba_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i108par___-ef2ed5097d6203fb9ff409855a1559a7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i108par___-ef2ed5097d6203fb9ff409855a1559a7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i109par___-84b39d7168b5e4be91e13577db900180.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i109par___-84b39d7168b5e4be91e13577db900180_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i10par___-443963dc5a68a396102a3d51ebe99933.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i10par___-443963dc5a68a396102a3d51ebe99933_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i110par___-661f27fe0eee45b8c7ad0b7012ab6368.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i110par___-661f27fe0eee45b8c7ad0b7012ab6368_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i111par___-7c5fa694cfd4c151e5fd475c48e08d68.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i111par___-7c5fa694cfd4c151e5fd475c48e08d68_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i112par___-933a237bd7ccfa9c6a06b3427ec896d1.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i112par___-933a237bd7ccfa9c6a06b3427ec896d1_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i113par___-3d7d6bb86229db9a83459f30307685bd.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i113par___-3d7d6bb86229db9a83459f30307685bd_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i114par___-84ad95823264975c6c91558c41bad2b1.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i114par___-84ad95823264975c6c91558c41bad2b1_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i115par___-58e725435af98ab844f4f4faf8f391bc.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i115par___-58e725435af98ab844f4f4faf8f391bc_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i116par___-c9b0b31286fa85d89c08ed778cdf5444.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i116par___-c9b0b31286fa85d89c08ed778cdf5444_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i117par___-3f45cae0efceee5ca194d2ab2411d6c6.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i117par___-3f45cae0efceee5ca194d2ab2411d6c6_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i118par___-1cc5361d55a78bb2ea289f90fffe0fc8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i118par___-1cc5361d55a78bb2ea289f90fffe0fc8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i119par___-b6b5cfe75b35317bf74bd51ca43dc2b0.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i119par___-b6b5cfe75b35317bf74bd51ca43dc2b0_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i11par___-d81014ce186c8808e45de50b1675e88e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i11par___-d81014ce186c8808e45de50b1675e88e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i120par___-83dda5161e1a1b92c0614c2418723b53.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i120par___-83dda5161e1a1b92c0614c2418723b53_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i121par___-4d910db8d7f99198d2d68cfd1dec4968.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i121par___-4d910db8d7f99198d2d68cfd1dec4968_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i122par___-aa20e87481a98cb0a32e60633a7e9ac8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i122par___-aa20e87481a98cb0a32e60633a7e9ac8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i123par___-fb1e718d3ed337809ad964c826562338.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i123par___-fb1e718d3ed337809ad964c826562338_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i124par___-4b1e023804b7aa5265f617f0c278c934.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i124par___-4b1e023804b7aa5265f617f0c278c934_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i125par___-95ab7527686837372bc4d7999145d05d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i125par___-95ab7527686837372bc4d7999145d05d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i126par___-4ef771ce2378df932f599a5d39271b35.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i126par___-4ef771ce2378df932f599a5d39271b35_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i127par___-8c88ba16f9d43321330edc5236fec4ca.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i127par___-8c88ba16f9d43321330edc5236fec4ca_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i128par___-428b2d62c2fa40312feda1fb6c538514.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i128par___-428b2d62c2fa40312feda1fb6c538514_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i129par___-be7b8753a23213c76eb99433f4b75c43.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i129par___-be7b8753a23213c76eb99433f4b75c43_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i12par___-81f7f484baaad137c1961201d7218167.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i12par___-81f7f484baaad137c1961201d7218167_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i130par___-17721fe6baa5c6591d14747e6fd22c6e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i130par___-17721fe6baa5c6591d14747e6fd22c6e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i131par___-aea61da3899f5cb05a273616d3cfbe19.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i131par___-aea61da3899f5cb05a273616d3cfbe19_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i132par___-752dfc300e8ff880bd396fb99e468ad3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i132par___-752dfc300e8ff880bd396fb99e468ad3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i133par___-4b5dc3b0bb12b8f56621caf372189f14.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i133par___-4b5dc3b0bb12b8f56621caf372189f14_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i134par___-cd0fad15bd7895d17d7906ec9d55878d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i134par___-cd0fad15bd7895d17d7906ec9d55878d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i135par___-401973892ccf0bfc5e032af7e8810c9f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i135par___-401973892ccf0bfc5e032af7e8810c9f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i136par___-8d2ebd42b1f40fc4cc640d970423f658.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i136par___-8d2ebd42b1f40fc4cc640d970423f658_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i137par___-12ed711884de15a8e94eefb69a132d11.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i137par___-12ed711884de15a8e94eefb69a132d11_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i138par___-0a5c3abcd7fb109a2d5b4ecb2556f44d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i138par___-0a5c3abcd7fb109a2d5b4ecb2556f44d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i139par___-5cc68cde4feb3686878c07298fe8f143.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i139par___-5cc68cde4feb3686878c07298fe8f143_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i13par___-20f330a2363e38b157d98866aa2576c2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i13par___-20f330a2363e38b157d98866aa2576c2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i140par___-16e08a976826a4208a92e7c66821eab2.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i140par___-16e08a976826a4208a92e7c66821eab2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i141par___-ed3d74197410c757c8b1510c85f2db67.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i141par___-ed3d74197410c757c8b1510c85f2db67_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i142par___-b0969396742b2f599ef99a49e580bc6a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i142par___-b0969396742b2f599ef99a49e580bc6a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i143par___-b5832e63b1602b2a43d9c9a07e5ff62f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i143par___-b5832e63b1602b2a43d9c9a07e5ff62f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i144par___-8c1fcf2b7a614ec2bef4ef0b51d95b77.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i144par___-8c1fcf2b7a614ec2bef4ef0b51d95b77_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i145par___-df99446c633037a2705605b4c55e1960.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i145par___-df99446c633037a2705605b4c55e1960_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i146par___-662a62d53d335b85a39b7e0f04a25ed7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i146par___-662a62d53d335b85a39b7e0f04a25ed7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i147par___-ee78aa277938739160c4ee28ce229054.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i147par___-ee78aa277938739160c4ee28ce229054_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i148par___-e5203fdb869ac179b7568d867a04a014.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i148par___-e5203fdb869ac179b7568d867a04a014_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i149par___-2d07be38ee82624f2b80a18c5a011b00.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i149par___-2d07be38ee82624f2b80a18c5a011b00_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i14par___-d8210b9a8403acd33a538925d20786d7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i14par___-d8210b9a8403acd33a538925d20786d7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i150par___-53710267a4edcf351c977fcaf78ebf35.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i150par___-53710267a4edcf351c977fcaf78ebf35_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i151par___-64597d2ac352801abe11937d62f0de6a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i151par___-64597d2ac352801abe11937d62f0de6a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i152par___-b3226b8ab7bc8cb1536339ecd6093e02.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i152par___-b3226b8ab7bc8cb1536339ecd6093e02_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i153par___-b89a9a6da8a825b17ee13cc433740773.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i153par___-b89a9a6da8a825b17ee13cc433740773_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i154par___-5c363b6b805a66f1485e49277fc14520.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i154par___-5c363b6b805a66f1485e49277fc14520_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i155par___-3703038ee7c077e400e0b8ab073018a4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i155par___-3703038ee7c077e400e0b8ab073018a4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i156par___-d15d68c09afe4f24b8664e06e285ada0.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i156par___-d15d68c09afe4f24b8664e06e285ada0_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i157par___-097c507c60612e0f03ccd19d33f372e3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i157par___-097c507c60612e0f03ccd19d33f372e3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i158par___-f913fd0ddaee471253315e2016ecca78.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i158par___-f913fd0ddaee471253315e2016ecca78_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i159par___-d9d637cc7eb793d16a6600cd1eba5f27.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i159par___-d9d637cc7eb793d16a6600cd1eba5f27_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i15par___-3d7aa1078e1527faaf2630ddfd331604.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i15par___-3d7aa1078e1527faaf2630ddfd331604_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i160par___-39d9c739961eca69bbc294fef069d5b9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i160par___-39d9c739961eca69bbc294fef069d5b9_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i161par___-4ba35533cd932673b8471618c13c87a2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i161par___-4ba35533cd932673b8471618c13c87a2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i162par___-068a5a48f19043a4a2cd409eafe370f5.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i162par___-068a5a48f19043a4a2cd409eafe370f5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i163par___-83a1c68c87e20f6e745f8321dc811eb5.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i163par___-83a1c68c87e20f6e745f8321dc811eb5_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i164par___-9adde5fd9de55498bf5db1dc2f470e01.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i164par___-9adde5fd9de55498bf5db1dc2f470e01_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:10
#
# 📸 20250624_183312i165par___-72b2adb6dc127fb4f8cf6f9f120275a9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:10
#
# ...
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i510par___-e12123b5410bba6a1658bf8f9c5c9dde.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i510par___-e12123b5410bba6a1658bf8f9c5c9dde_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i511par___-5ec2bbd0b880103d856adcadd13b661a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i511par___-5ec2bbd0b880103d856adcadd13b661a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i512par___-abad64c011a2d354fc327bed7a82cb73.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i512par___-abad64c011a2d354fc327bed7a82cb73_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i513par___-1375968321b06b847433f4df1bb98b31.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i513par___-1375968321b06b847433f4df1bb98b31_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i514par___-2c9a4c8f0f0d23eb303a2aa0fec67b4d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i514par___-2c9a4c8f0f0d23eb303a2aa0fec67b4d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i515par___-d00f7d8443841b28ea41c87039145afa.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i515par___-d00f7d8443841b28ea41c87039145afa_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i516par___-84ee78876eab24b583f74f9d7dd3e542.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i516par___-84ee78876eab24b583f74f9d7dd3e542_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i51par___-6dfd9ef64004fe9df0ca98ae59f77d73.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i51par___-6dfd9ef64004fe9df0ca98ae59f77d73_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i52par___-998020d201dba5fa7977ff72cdf7ad70.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i52par___-998020d201dba5fa7977ff72cdf7ad70_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i53par___-06499ff519217ef265342d3462b68b4a.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i53par___-06499ff519217ef265342d3462b68b4a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i54par___-d48e1ec58fc0819ef54449548e1f864b.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i54par___-d48e1ec58fc0819ef54449548e1f864b_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i55par___-0a7b6c2e80c82f5c716a11934bcc5093.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i55par___-0a7b6c2e80c82f5c716a11934bcc5093_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i56par___-872e3cfcecea174db548323b6f4909e7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i56par___-872e3cfcecea174db548323b6f4909e7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i57par___-abbf8817732f3ba02a0bc252b424c13a.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i57par___-abbf8817732f3ba02a0bc252b424c13a_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i58par___-3e80f71a0a135b626dfd721da747a0eb.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i58par___-3e80f71a0a135b626dfd721da747a0eb_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i59par___-ce765fffdadb9a3faa477507c60ca6b7.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i59par___-ce765fffdadb9a3faa477507c60ca6b7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i5par___-0ff1c192a14813dab805ea41f028e9a2.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i5par___-0ff1c192a14813dab805ea41f028e9a2_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i60par___-bbdddf118c4ee0d657789b0412cad8f4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i60par___-bbdddf118c4ee0d657789b0412cad8f4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i61par___-811b486ce6447c5aa7ba034bd3b6dd10.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i61par___-811b486ce6447c5aa7ba034bd3b6dd10_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i62par___-5eaee15d5734dc55f56be9d349a59e09.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i62par___-5eaee15d5734dc55f56be9d349a59e09_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i63par___-06b765b884a8a6351706b76647d11549.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i63par___-06b765b884a8a6351706b76647d11549_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i64par___-5f9dd3487f20e90ea53f2d565e75a7b3.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i64par___-5f9dd3487f20e90ea53f2d565e75a7b3_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i65par___-f5ed8dab12d3813b584c19ac679381cd.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i65par___-f5ed8dab12d3813b584c19ac679381cd_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i66par___-5e5eb0a4ccbe3a352e710513c4712618.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i66par___-5e5eb0a4ccbe3a352e710513c4712618_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i67par___-11590e1d91531a5a28b7af3828834c4e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i67par___-11590e1d91531a5a28b7af3828834c4e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i68par___-ad9109f9c30f7b0c770c7c7b234a8129.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i68par___-ad9109f9c30f7b0c770c7c7b234a8129_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i69par___-3035bdf603253daa2bc8536f727d0866.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i69par___-3035bdf603253daa2bc8536f727d0866_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i6par___-49755e17a73ebf285bce49490e78e00f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i6par___-49755e17a73ebf285bce49490e78e00f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i70par___-268498bae7c05b4008aa753d12217c0e.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i70par___-268498bae7c05b4008aa753d12217c0e_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i71par___-e58669db24dce384391718d4a08f1e2f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i71par___-e58669db24dce384391718d4a08f1e2f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i72par___-292fcee7e4ad56a78e8bb4826e88dd5f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i72par___-292fcee7e4ad56a78e8bb4826e88dd5f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i73par___-d93618129b2b41b535210eac44a4bd3f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i73par___-d93618129b2b41b535210eac44a4bd3f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i74par___-144addad359bd893b6cf8b05760a798f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i74par___-144addad359bd893b6cf8b05760a798f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i75par___-adb20d7e0d66a827be61c08199371c11.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i75par___-adb20d7e0d66a827be61c08199371c11_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i76par___-cd21ab74251142133c6a1f51563293d8.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i76par___-cd21ab74251142133c6a1f51563293d8_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i77par___-93a60d5bcfbec0ec20b3049c72ae8c61.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i77par___-93a60d5bcfbec0ec20b3049c72ae8c61_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i78par___-86f0e52b3d4f1c1d81b066c273a2111d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i78par___-86f0e52b3d4f1c1d81b066c273a2111d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i79par___-1cf90036a03fb63d3c800b3eec9bc841.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i79par___-1cf90036a03fb63d3c800b3eec9bc841_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i7par___-bee8bf48a984a0916843b6552df17dca.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i7par___-bee8bf48a984a0916843b6552df17dca_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i80par___-a89fda46d3e79068da70ad17a964f4d4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i80par___-a89fda46d3e79068da70ad17a964f4d4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i81par___-8ea916d3a13d577dd104f1d4d534e640.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i81par___-8ea916d3a13d577dd104f1d4d534e640_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i82par___-abb5e416c9268674c8a3f30a3824d6b4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i82par___-abb5e416c9268674c8a3f30a3824d6b4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i83par___-22dcfffac2c8672e80c5e0e90fe1a60d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i83par___-22dcfffac2c8672e80c5e0e90fe1a60d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i84par___-e1f947db1396d5748074d73fab2562de.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i84par___-e1f947db1396d5748074d73fab2562de_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i85par___-5ab68be8565df38a93fa5d8048c38ce1.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i85par___-5ab68be8565df38a93fa5d8048c38ce1_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i86par___-c662f21e3ef201f126658b00f9de5602.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i86par___-c662f21e3ef201f126658b00f9de5602_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i87par___-368ba8ccabc1eb43eec0bdb881139148.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i87par___-368ba8ccabc1eb43eec0bdb881139148_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i88par___-2c504cf322ebf287416d9ab15cf4d2f7.png
#    Size: 0.09 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i88par___-2c504cf322ebf287416d9ab15cf4d2f7_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i89par___-7c87014f64ff65fa2d84151b2e72485c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i89par___-7c87014f64ff65fa2d84151b2e72485c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i8par___-b825b6baec826bb86e6ffe1dd8afadab.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i8par___-b825b6baec826bb86e6ffe1dd8afadab_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i90par___-902f7e05fddbe26f8d9b5a4a2e655fda.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i90par___-902f7e05fddbe26f8d9b5a4a2e655fda_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i91par___-0e4083a06c91bce779e97e07f0cc6716.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i91par___-0e4083a06c91bce779e97e07f0cc6716_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i92par___-0d9efb32efd1ba2b4a5151fb5237201c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i92par___-0d9efb32efd1ba2b4a5151fb5237201c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i93par___-9d5ef640690fd3f9b9e9f1c980d8e91d.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i93par___-9d5ef640690fd3f9b9e9f1c980d8e91d_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i94par___-f61882fc32037b99c701437fbeec3b21.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i94par___-f61882fc32037b99c701437fbeec3b21_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i95par___-fb435eab784ab78f466e8610e26e9087.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i95par___-fb435eab784ab78f466e8610e26e9087_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i96par___-029fb55b949d5e89eaba3f9bd192a618.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i96par___-029fb55b949d5e89eaba3f9bd192a618_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i97par___-032216a896e9d74aeb57812e87a33cd9.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i97par___-032216a896e9d74aeb57812e87a33cd9_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i98par___-df9b5b4c177d64c54d857e3ef9bbbaf4.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i98par___-df9b5b4c177d64c54d857e3ef9bbbaf4_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i99par___-d7e6eeb476a0c0168c664d4f4fa41c9f.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i99par___-d7e6eeb476a0c0168c664d4f4fa41c9f_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i9par___-3dc460cb8457b0e95e7cb016835d524c.png
#    Size: 0.10 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 20250624_183312i9par___-3dc460cb8457b0e95e7cb016835d524c_dist.png
#    Size: 0.06 MB
#    Modified: 2025-07-02 01:24:11
#
# 📸 fallback-image.png
#    Size: 0.15 MB
#    Modified: 2025-07-03 23:22:02
#
# 💾 Total image size: 100.20 MB
#
# DIRECTORY STRUCTURE:
# --------------------------------------------------
# plots/
#   20250624_183312i458par___-4ed006ee6e69cf6ef75eb6c89ecd5e4a_dist.png
#   20250624_183312i425par___-0e4f9c459b4f05cd9a4bbaf36cc0c21b.png
#   20250624_183312i31par___-aa5b90705191bff10292a628c6858d43.png
#   20250624_183312i318par___-537aa6e0790e33e48926a3f8a80c2132_dist.png
#   20250624_183312i400par___-d317fa8cc1291045192a1a0be7081518.png
#   ... and 1287 more files
#
# ============================================================
# DOCKER MOUNT COMPATIBILITY CHECK
# ============================================================
# ✅ ../backend
# ✅ ../backend/app
# ✅ ../backend/app/static
# ✅ ../backend/app/static/plots
#
# Current directory contains:
#    📄 batch_evaluation_results.csv
#    📄 pp21cakelarge300cutoff20trip16btb1 (1).csv
#    📄 utilities_by_iteration_agh.csv
#    📄 evaluation_results_SELECTED.csv
#    📄 upload.py
#    📄 exam_sizes.csv
#    📄 utility_plots
#    📄 plotting.py
#    📄 pp22cakelarge300cutoff18trip16btb1.csv
#    📄 __init__.py
#    📄 upload_results.log
#    📄 get_metrics.ipynb
#    📄 __pycache__
#    📄 pp22cakelarge300cutoff19trip16btb1.csv
#    📄 results
#    📄 workflow.ipynb
#    📄 SELECTED.csv
#    📄 upload_schedules.log
#    📄 evaluate.py
#    📄 utilities_by_iteration_eubo.csv
#    📄 upload_images.log
#    📄 pp21cakelarge300cutoff19trip16btb1 (1).csv
#    📄 plots
#
# ⚠️  Missing expected files: ['backend', 'docker-compose.yml', 'Dockerfile']
#    You might not be in the project root directory

# %%
#!/usr/bin/env python3
"""
Test script for metrics upload functionality
Creates sample metrics CSV files and tests the upload process
"""

import os
import pandas as pd
import tempfile
import shutil
#from metrics.upload import metrics_csv_upload, check_api_health
import logging

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def create_sample_metrics_csvs(temp_dir: str, num_files: int = 5) -> str:
    """
    Create sample metrics CSV files for testing
    
    Args:
        temp_dir: Directory to create files in
        num_files: Number of sample files to create
        
    Returns:
        Path to directory containing sample files
    """
    metrics_dir = os.path.join(temp_dir, "metrics")
    os.makedirs(metrics_dir, exist_ok=True)
    
    # Sample metrics data matching your schema
    sample_data = {
        "conflicts": [0, 1, 2, 0, 1],
        "quints": [0, 0, 1, 0, 0], 
        "quads": [1, 2, 1, 3, 2],
        "four in five slots": [2, 3, 1, 4, 2],
        "triple in 24h (no gaps)": [3, 2, 4, 1, 3],
        "triple in same day (no gaps)": [1, 1, 2, 0, 1],
        "three in four slots": [4, 3, 5, 2, 4],
        "evening/morning b2b": [0, 1, 0, 2, 1],
        "other b2b": [2, 1, 3, 1, 2],
        "two in three slots": [5, 4, 6, 3, 5],
        "singular late exam": [1, 0, 1, 2, 1],
        "two exams, large gap": [0, 1, 0, 1, 0],
        "avg_max": [0.75, 0.82, 0.68, 0.91, 0.77],
        "lateness": [10, 15, 8, 20, 12],
        "size_cutoff": [100, 150, 120, 180, 130],
        "reserved": [5, 8, 6, 10, 7],
        "num_blocks": [12, 15, 11, 18, 14],
        "alpha": [0.1, 0.15, 0.12, 0.08, 0.13],
        "gamma": [0.2, 0.25, 0.18, 0.22, 0.21],
        "delta": [0.3, 0.28, 0.32, 0.27, 0.29],
        "vega": [0.05, 0.08, 0.06, 0.04, 0.07],
        "theta": [0.15, 0.12, 0.18, 0.14, 0.16],
        "large_block_size": [1.5, 1.8, 1.6, 2.0, 1.7],
        "large_exam_weight": [2.0, 2.5, 2.2, 1.8, 2.3],
        "large_block_weight": [1.2, 1.5, 1.3, 1.0, 1.4],
        "large_size_1": [0.8, 0.9, 0.85, 0.75, 0.88],
        "large_cutoff_freedom": [0.6, 0.7, 0.65, 0.55, 0.68],
        "tradeoff": [0.4, 0.45, 0.42, 0.38, 0.43],
        "flpens": [0.25, 0.3, 0.28, 0.22, 0.27]
    }
    
    # Create individual CSV files
    for i in range(num_files):
        # Create single-row DataFrame for this schedule
        row_data = {col: [values[i]] for col, values in sample_data.items()}
        df = pd.DataFrame(row_data)
        
        # Save to CSV file
        filename = f"schedule_{i+1:03d}.csv"
        filepath = os.path.join(metrics_dir, filename)
        df.to_csv(filepath, index=False)
        
        logger.info(f"Created sample file: {filename}")
    
    logger.info(f"Created {num_files} sample metrics CSV files in {metrics_dir}")
    return metrics_dir


def test_api_endpoints():
    """Test API health and endpoints"""
    logger.info("Testing API endpoints...")
    
    api_url = "http://localhost:5000"  # Adjust for your local setup
    
    # Test health endpoint
    if check_api_health(api_url):
        logger.info("✅ API health check passed")
    else:
        logger.error("❌ API health check failed")
        return False
    
    return True


def test_complete_workflow():
    """Test the complete metrics upload workflow"""
    logger.info("Starting complete workflow test...")
    
    # Create temporary directory
    with tempfile.TemporaryDirectory() as temp_dir:
        logger.info(f"Using temporary directory: {temp_dir}")
        
        # Step 1: Create sample CSV files
        metrics_dir = create_sample_metrics_csvs(temp_dir, num_files=3)
        
        # Step 2: Test API health
        if not test_api_endpoints():
            logger.error("API endpoints not available - skipping upload test")
            return False
        
        # Step 3: Test upload (dry run first)
        logger.info("Testing dry run...")
        
        # Import and test dry run logic
        from metrics.upload import find_metrics_csv_files, combine_metrics_csvs
        
        csv_files = find_metrics_csv_files(metrics_dir)
        logger.info(f"Found {len(csv_files)} CSV files")
        
        combined_df = combine_metrics_csvs(csv_files, "test_semester")
        if combined_df is not None:
            logger.info(f"✅ Successfully combined {len(combined_df)} records")
            logger.info(f"Columns: {list(combined_df.columns)}")
            logger.info("Sample data:")
            print(combined_df.head())
        else:
            logger.error("❌ Failed to combine CSV files")
            return False
        
        # Step 4: Test actual upload (uncomment when API is running)
        # logger.info("Testing actual upload...")
        # success = metrics_csv_upload(
        #     metrics_dir, 
        #     semester="test_semester",
        #     api_url="http://localhost:5000"
        # )
        # 
        # if success:
        #     logger.info("✅ Upload test successful")
        # else:
        #     logger.error("❌ Upload test failed")
        #     return False
    
    logger.info("✅ Complete workflow test passed!")
    return True


def main():
    """Run all tests"""
    logger.info("=" * 60)
    logger.info("METRICS UPLOAD TEST SUITE")
    logger.info("=" * 60)
    
    try:
        # Test the complete workflow
        if test_complete_workflow():
            logger.info("🎉 All tests passed!")
        else:
            logger.error("💥 Some tests failed!")
            
    except Exception as e:
        logger.error(f"💥 Test suite failed with error: {e}")
        import traceback
        traceback.print_exc()


if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       9 import tempfile
#      10 import shutil
# ---> 11 from metrics.upload import metrics_csv_upload, check_api_health
#      12 import logging
#      14 # Setup logging
#
# ModuleNotFoundError: No module named 'metrics'
